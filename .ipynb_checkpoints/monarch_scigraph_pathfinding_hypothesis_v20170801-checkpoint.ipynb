# %% [markdown]
# ## Query scigraph for linking two nodes (pathfinding), and add hypothesis into the network
# * Monarch API: **scigraph**
# https://scigraph-data.monarchinitiative.org/scigraph/docs/
# * API endpoint: **dynamic** (Cypher dynamic resources)
# `GET /dynamic/shortest`
# _"Get the shortest path between two IDs"_

# %%
import sys, os
import requests
import json

# output directory
outdir = os.getcwd() + '/scigraph-paths'
if not os.path.isdir(outdir): os.makedirs(outdir)

sys.path.insert(0, './scigraph-paths')

# %% [markdown]
# ### Get hypothesis

# %% [markdown]
# #### Testing the api and design the experiment

# %%
# test api: '/dynamic/shortest'
api = 'https://scigraph-data.monarchinitiative.org/scigraph'
endpoint = '/dynamic/shortest'

# nodes
s1 = 'OMIM:615273'
s2 = 'NCBIGene:55768'
e1 = 'NCBIGene:358'
e2 = 'NCBIGene:11826'
e3 = 'CHEBI:506227'
md = '15'

# %%
# hypothesis for s1-e1 
data = {'start_id':s1,'end_id':e1, 'max_depth':md}

r = requests.get('{}{}'.format(api,endpoint), params=data)
r.headers
r.status_code
# Out:
# 500

# %% [markdown]
# #### scigraph github open issue answered:
# * https://github.com/SciGraph/SciGraph/issues/242
#
# The endpoint __/dynamic/shortest__ does not work.
# As a work around, you can use the cypher execution service __/cypher/execute__:

# %%
# test api: the cypher service '/cypher/execute'
# api address
api = 'https://scigraph-data.monarchinitiative.org/scigraph'
endpoint = '/cypher/execute.json'

# cypher query - single shortest path [shortestPath()]
queryOld='''
      MATCH path = shortestPath(
       (start:Node{iri:'http://purl.obolibrary.org/obo/HP_0100750'})-[:subClassOf|equivalentClass*..4]->(end:Node{iri:'http://purl.obolibrary.org/obo/MP_0005388'})
      )
      RETURN path
'''

obo = 'http://purl.obolibrary.org/obo/'
s = obo + 'HP_0100750'
r = ':subClassOf|equivalentClass'
md = '4'
e = obo + 'MP_0005388'
query='''
      MATCH path = shortestPath(
       (start:Node{iri:"'''+s+'''"})-['''+r+'''*..'''+md+''']->(end:Node{iri:"'''+e+'''"})
      )
      RETURN path
'''

# api call 
data = {
    'cypherQuery':query,
    'limit':1000
}
r = requests.get('{}{}'.format(api,endpoint), params=data)
r.headers
r.status_code
print('Path-overview: {}'.format(r.json()[0]['path']['overview']))
print('Path-details: {}'.format(r.json()[0]['path']['details']))
r.json()
# Out:
# Path-overview: (1709066)--[subClassOf,130265431]-->(2572968)--[subClassOf,127139203]-->(749956)
# Path-details: [{'iri': 'http://purl.obolibrary.org/obo/HP_0100750', 'http://www.geneontology.org/formats/oboInOwl#creation_date': '2011-06-06T06:38:53Z', 'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Pulmonary atelectasis', 'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['SNOMEDCT_US:46621007', 'UMLS:C0004144', 'MSH:D001261'], 'http://www.geneontology.org/formats/oboInOwl#created_by': 'doelkens', 'label': 'Atelectasis', 'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0100750', 'synonym': 'Pulmonary atelectasis', 'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype', 'http://www.w3.org/2000/01/rdf-schema#label': 'Atelectasis', 'definition': 'Collapse of part of a lung associated with absence of inflation (air) of that part.', 'http://purl.obolibrary.org/obo/IAO_0000115': 'Collapse of part of a lung associated with absence of inflation (air) of that part.', 'category': 'Phenotype', 'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader']}, {'type': 'subClassOf', 'lbl': 'subClassOf', 'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl', 'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0001177', 'equivalentOriginalNodeTarget': 'http://purl.obolibrary.org/obo/MP_0001943'}, {'category': 'Phenotype', 'iri': 'http://purl.obolibrary.org/obo/HP_0002795', 'synonym': ['Respiratory problem', 'Functional respiratory abnormality'], 'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795', 'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Functional respiratory abnormality', 'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype', 'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.', 'http://www.geneontology.org/formats/oboInOwl#hasDbXref': 'UMLS:C4025677', 'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem', 'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality', 'label': 'Functional respiratory abnormality', 'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader']}, {'type': 'subClassOf', 'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl', 'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0002327', 'lbl': 'subClassOf'}, {'iri': 'http://purl.obolibrary.org/obo/MP_0005388', 'http://www.w3.org/2000/01/rdf-schema#label': 'respiratory system phenotype', 'http://www.geneontology.org/formats/oboInOwl#id': 'MP:0005388', 'category': 'Phenotype', 'label': 'respiratory system phenotype', 'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'MPheno.ontology', 'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader']}]
# [{'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'Phenotype',
#       'cliqueLeader'],
#      'category': 'Phenotype',
#      'definition': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://purl.obolibrary.org/obo/IAO_0000115': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://www.geneontology.org/formats/oboInOwl#created_by': 'doelkens',
#      'http://www.geneontology.org/formats/oboInOwl#creation_date': '2011-06-06T06:38:53Z',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['SNOMEDCT_US:46621007',
#       'UMLS:C0004144',
#       'MSH:D001261'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Pulmonary atelectasis',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0100750',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Atelectasis',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0100750',
#      'label': 'Atelectasis',
#      'synonym': 'Pulmonary atelectasis'},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0001177',
#      'equivalentOriginalNodeTarget': 'http://purl.obolibrary.org/obo/MP_0001943',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': 'UMLS:C4025677',
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Functional respiratory abnormality',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795',
#      'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0002795',
#      'label': 'Functional respiratory abnormality',
#      'synonym': ['Respiratory problem', 'Functional respiratory abnormality']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0002327',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'MPheno.ontology',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'MP:0005388',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'respiratory system phenotype',
#      'iri': 'http://purl.obolibrary.org/obo/MP_0005388',
#      'label': 'respiratory system phenotype'}],
#    'overview': '(1709066)--[subClassOf,130265431]-->(2572968)--[subClassOf,127139203]-->(749956)'}}]

# %%
# test the cypher service changing the query
# api address
api = 'https://scigraph-data.monarchinitiative.org/scigraph'
endpoint = '/cypher/execute.json'

# cypher query - single shortest path [shortestPath()] + changing relation_types and max_depth (md)

obo = 'http://purl.obolibrary.org/obo/'
s = obo + 'HP_0100750'
#r = ':subClassOf|equivalentClass'
r = ''
md = '10'
e = obo + 'MP_0005388'
query='''
      MATCH path = shortestPath(
       (start:Node{iri:"'''+s+'''"})-['''+r+'''*..'''+md+''']->(end:Node{iri:"'''+e+'''"})
      )
      RETURN path
'''

# api call 
data = {
    'cypherQuery':query,
    'limit':1000
}
r = requests.get('{}{}'.format(api,endpoint), params=data)
r.headers
r.status_code
print('Path-overview: {}'.format(r.json()[0]['path']['overview']))
print('Path-details: {}'.format(r.json()[0]['path']['details']))
r.json()
# Out:
# Path-overview: (1709066)--[subClassOf,130265431]-->(2572968)--[subClassOf,127139203]-->(749956)
# Path-details: [{'iri': 'http://purl.obolibrary.org/obo/HP_0100750', 'http://www.geneontology.org/formats/oboInOwl#creation_date': '2011-06-06T06:38:53Z', 'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Pulmonary atelectasis', 'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['SNOMEDCT_US:46621007', 'UMLS:C0004144', 'MSH:D001261'], 'http://www.geneontology.org/formats/oboInOwl#created_by': 'doelkens', 'label': 'Atelectasis', 'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0100750', 'synonym': 'Pulmonary atelectasis', 'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype', 'http://www.w3.org/2000/01/rdf-schema#label': 'Atelectasis', 'definition': 'Collapse of part of a lung associated with absence of inflation (air) of that part.', 'http://purl.obolibrary.org/obo/IAO_0000115': 'Collapse of part of a lung associated with absence of inflation (air) of that part.', 'category': 'Phenotype', 'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader']}, {'type': 'subClassOf', 'lbl': 'subClassOf', 'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl', 'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0001177', 'equivalentOriginalNodeTarget': 'http://purl.obolibrary.org/obo/MP_0001943'}, {'category': 'Phenotype', 'iri': 'http://purl.obolibrary.org/obo/HP_0002795', 'synonym': ['Respiratory problem', 'Functional respiratory abnormality'], 'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795', 'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Functional respiratory abnormality', 'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype', 'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.', 'http://www.geneontology.org/formats/oboInOwl#hasDbXref': 'UMLS:C4025677', 'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem', 'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality', 'label': 'Functional respiratory abnormality', 'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader']}, {'type': 'subClassOf', 'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl', 'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0002327', 'lbl': 'subClassOf'}, {'iri': 'http://purl.obolibrary.org/obo/MP_0005388', 'http://www.w3.org/2000/01/rdf-schema#label': 'respiratory system phenotype', 'http://www.geneontology.org/formats/oboInOwl#id': 'MP:0005388', 'category': 'Phenotype', 'label': 'respiratory system phenotype', 'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'MPheno.ontology', 'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader']}]
# [{'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'Phenotype',
#       'cliqueLeader'],
#      'category': 'Phenotype',
#      'definition': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://purl.obolibrary.org/obo/IAO_0000115': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://www.geneontology.org/formats/oboInOwl#created_by': 'doelkens',
#      'http://www.geneontology.org/formats/oboInOwl#creation_date': '2011-06-06T06:38:53Z',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['SNOMEDCT_US:46621007',
#       'UMLS:C0004144',
#       'MSH:D001261'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Pulmonary atelectasis',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0100750',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Atelectasis',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0100750',
#      'label': 'Atelectasis',
#      'synonym': 'Pulmonary atelectasis'},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0001177',
#      'equivalentOriginalNodeTarget': 'http://purl.obolibrary.org/obo/MP_0001943',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': 'UMLS:C4025677',
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Functional respiratory abnormality',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795',
#      'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0002795',
#      'label': 'Functional respiratory abnormality',
#      'synonym': ['Respiratory problem', 'Functional respiratory abnormality']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0002327',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'MPheno.ontology',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'MP:0005388',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'respiratory system phenotype',
#      'iri': 'http://purl.obolibrary.org/obo/MP_0005388',
#      'label': 'respiratory system phenotype'}],
#    'overview': '(1709066)--[subClassOf,130265431]-->(2572968)--[subClassOf,127139203]-->(749956)'}}]

# %%
# test the cypher service to query with the function 'allShortestPaths()' 

# cypher query - all shortest paths [allShortestPaths()]

obo = 'http://purl.obolibrary.org/obo/'
s = obo + 'HP_0100750'
r = ':subClassOf|equivalentClass'
md = '4'
e = obo + 'MP_0005388'
query='''
      MATCH path = allShortestPaths(
       (start:Node{iri:"'''+s+'''"})-['''+r+'''*..'''+md+''']->(end:Node{iri:"'''+e+'''"})
      )
      RETURN path
'''

# api call 
data = {
    'cypherQuery':query,
    'limit':1000
}
r = requests.get('{}{}'.format(api,endpoint), params=data)
r.headers
r.status_code
print('Path-overview: {}'.format(r.json()[0]['path']['overview']))
print('Path-details: {}'.format(r.json()[0]['path']['details']))
print('number of paths: {}'.format(len(r.json())))
r.json()
# Out:
# Path-overview: (1709066)--[subClassOf,130265431]-->(2572968)--[subClassOf,127139203]-->(749956)
# Path-details: [{'iri': 'http://purl.obolibrary.org/obo/HP_0100750', 'http://www.geneontology.org/formats/oboInOwl#creation_date': '2011-06-06T06:38:53Z', 'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Pulmonary atelectasis', 'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['SNOMEDCT_US:46621007', 'UMLS:C0004144', 'MSH:D001261'], 'http://www.geneontology.org/formats/oboInOwl#created_by': 'doelkens', 'label': 'Atelectasis', 'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0100750', 'synonym': 'Pulmonary atelectasis', 'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype', 'http://www.w3.org/2000/01/rdf-schema#label': 'Atelectasis', 'definition': 'Collapse of part of a lung associated with absence of inflation (air) of that part.', 'http://purl.obolibrary.org/obo/IAO_0000115': 'Collapse of part of a lung associated with absence of inflation (air) of that part.', 'category': 'Phenotype', 'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader']}, {'type': 'subClassOf', 'lbl': 'subClassOf', 'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl', 'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0001177', 'equivalentOriginalNodeTarget': 'http://purl.obolibrary.org/obo/MP_0001943'}, {'category': 'Phenotype', 'iri': 'http://purl.obolibrary.org/obo/HP_0002795', 'synonym': ['Respiratory problem', 'Functional respiratory abnormality'], 'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795', 'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Functional respiratory abnormality', 'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype', 'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.', 'http://www.geneontology.org/formats/oboInOwl#hasDbXref': 'UMLS:C4025677', 'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem', 'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality', 'label': 'Functional respiratory abnormality', 'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader']}, {'type': 'subClassOf', 'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl', 'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0002327', 'lbl': 'subClassOf'}, {'iri': 'http://purl.obolibrary.org/obo/MP_0005388', 'http://www.w3.org/2000/01/rdf-schema#label': 'respiratory system phenotype', 'http://www.geneontology.org/formats/oboInOwl#id': 'MP:0005388', 'category': 'Phenotype', 'label': 'respiratory system phenotype', 'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'MPheno.ontology', 'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader']}]
# number of paths: 32
# [{'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'Phenotype',
#       'cliqueLeader'],
#      'category': 'Phenotype',
#      'definition': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://purl.obolibrary.org/obo/IAO_0000115': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://www.geneontology.org/formats/oboInOwl#created_by': 'doelkens',
#      'http://www.geneontology.org/formats/oboInOwl#creation_date': '2011-06-06T06:38:53Z',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['SNOMEDCT_US:46621007',
#       'UMLS:C0004144',
#       'MSH:D001261'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Pulmonary atelectasis',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0100750',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Atelectasis',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0100750',
#      'label': 'Atelectasis',
#      'synonym': 'Pulmonary atelectasis'},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0001177',
#      'equivalentOriginalNodeTarget': 'http://purl.obolibrary.org/obo/MP_0001943',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': 'UMLS:C4025677',
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Functional respiratory abnormality',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795',
#      'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0002795',
#      'label': 'Functional respiratory abnormality',
#      'synonym': ['Respiratory problem', 'Functional respiratory abnormality']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0002327',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'MPheno.ontology',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'MP:0005388',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'respiratory system phenotype',
#      'iri': 'http://purl.obolibrary.org/obo/MP_0005388',
#      'label': 'respiratory system phenotype'}],
#    'overview': '(1709066)--[subClassOf,130265431]-->(2572968)--[subClassOf,127139203]-->(749956)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'Phenotype',
#       'cliqueLeader'],
#      'category': 'Phenotype',
#      'definition': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://purl.obolibrary.org/obo/IAO_0000115': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://www.geneontology.org/formats/oboInOwl#created_by': 'doelkens',
#      'http://www.geneontology.org/formats/oboInOwl#creation_date': '2011-06-06T06:38:53Z',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['SNOMEDCT_US:46621007',
#       'UMLS:C0004144',
#       'MSH:D001261'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Pulmonary atelectasis',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0100750',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Atelectasis',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0100750',
#      'label': 'Atelectasis',
#      'synonym': 'Pulmonary atelectasis'},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0001177',
#      'equivalentOriginalNodeTarget': 'http://purl.obolibrary.org/obo/MP_0001943',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': 'UMLS:C4025677',
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Functional respiratory abnormality',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795',
#      'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0002795',
#      'label': 'Functional respiratory abnormality',
#      'synonym': ['Respiratory problem', 'Functional respiratory abnormality']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0001943',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'MPheno.ontology',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'MP:0005388',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'respiratory system phenotype',
#      'iri': 'http://purl.obolibrary.org/obo/MP_0005388',
#      'label': 'respiratory system phenotype'}],
#    'overview': '(1709066)--[subClassOf,130265431]-->(2572968)--[subClassOf,127138940]-->(749956)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'Phenotype',
#       'cliqueLeader'],
#      'category': 'Phenotype',
#      'definition': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://purl.obolibrary.org/obo/IAO_0000115': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://www.geneontology.org/formats/oboInOwl#created_by': 'doelkens',
#      'http://www.geneontology.org/formats/oboInOwl#creation_date': '2011-06-06T06:38:53Z',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['SNOMEDCT_US:46621007',
#       'UMLS:C0004144',
#       'MSH:D001261'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Pulmonary atelectasis',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0100750',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Atelectasis',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0100750',
#      'label': 'Atelectasis',
#      'synonym': 'Pulmonary atelectasis'},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0001177',
#      'equivalentOriginalNodeTarget': 'http://purl.obolibrary.org/obo/MP_0001943',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': 'UMLS:C4025677',
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Functional respiratory abnormality',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795',
#      'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0002795',
#      'label': 'Functional respiratory abnormality',
#      'synonym': ['Respiratory problem', 'Functional respiratory abnormality']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0002133',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'MPheno.ontology',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'MP:0005388',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'respiratory system phenotype',
#      'iri': 'http://purl.obolibrary.org/obo/MP_0005388',
#      'label': 'respiratory system phenotype'}],
#    'overview': '(1709066)--[subClassOf,130265431]-->(2572968)--[subClassOf,127139337]-->(749956)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'Phenotype',
#       'cliqueLeader'],
#      'category': 'Phenotype',
#      'definition': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://purl.obolibrary.org/obo/IAO_0000115': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://www.geneontology.org/formats/oboInOwl#created_by': 'doelkens',
#      'http://www.geneontology.org/formats/oboInOwl#creation_date': '2011-06-06T06:38:53Z',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['SNOMEDCT_US:46621007',
#       'UMLS:C0004144',
#       'MSH:D001261'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Pulmonary atelectasis',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0100750',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Atelectasis',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0100750',
#      'label': 'Atelectasis',
#      'synonym': 'Pulmonary atelectasis'},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0001177',
#      'equivalentOriginalNodeTarget': 'http://purl.obolibrary.org/obo/MP_0001943',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': 'UMLS:C4025677',
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Functional respiratory abnormality',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795',
#      'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0002795',
#      'label': 'Functional respiratory abnormality',
#      'synonym': ['Respiratory problem', 'Functional respiratory abnormality']},
#     {'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'MPheno.ontology',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'MP:0005388',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'respiratory system phenotype',
#      'iri': 'http://purl.obolibrary.org/obo/MP_0005388',
#      'label': 'respiratory system phenotype'}],
#    'overview': '(1709066)--[subClassOf,130265431]-->(2572968)--[subClassOf,23413018]-->(749956)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'Phenotype',
#       'cliqueLeader'],
#      'category': 'Phenotype',
#      'definition': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://purl.obolibrary.org/obo/IAO_0000115': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://www.geneontology.org/formats/oboInOwl#created_by': 'doelkens',
#      'http://www.geneontology.org/formats/oboInOwl#creation_date': '2011-06-06T06:38:53Z',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['SNOMEDCT_US:46621007',
#       'UMLS:C0004144',
#       'MSH:D001261'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Pulmonary atelectasis',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0100750',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Atelectasis',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0100750',
#      'label': 'Atelectasis',
#      'synonym': 'Pulmonary atelectasis'},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0001177',
#      'equivalentOriginalNodeTarget': 'http://purl.obolibrary.org/obo/MP_0002327',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': 'UMLS:C4025677',
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Functional respiratory abnormality',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795',
#      'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0002795',
#      'label': 'Functional respiratory abnormality',
#      'synonym': ['Respiratory problem', 'Functional respiratory abnormality']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0002327',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'MPheno.ontology',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'MP:0005388',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'respiratory system phenotype',
#      'iri': 'http://purl.obolibrary.org/obo/MP_0005388',
#      'label': 'respiratory system phenotype'}],
#    'overview': '(1709066)--[subClassOf,130265430]-->(2572968)--[subClassOf,127139203]-->(749956)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'Phenotype',
#       'cliqueLeader'],
#      'category': 'Phenotype',
#      'definition': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://purl.obolibrary.org/obo/IAO_0000115': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://www.geneontology.org/formats/oboInOwl#created_by': 'doelkens',
#      'http://www.geneontology.org/formats/oboInOwl#creation_date': '2011-06-06T06:38:53Z',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['SNOMEDCT_US:46621007',
#       'UMLS:C0004144',
#       'MSH:D001261'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Pulmonary atelectasis',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0100750',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Atelectasis',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0100750',
#      'label': 'Atelectasis',
#      'synonym': 'Pulmonary atelectasis'},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0001177',
#      'equivalentOriginalNodeTarget': 'http://purl.obolibrary.org/obo/MP_0002327',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': 'UMLS:C4025677',
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Functional respiratory abnormality',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795',
#      'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0002795',
#      'label': 'Functional respiratory abnormality',
#      'synonym': ['Respiratory problem', 'Functional respiratory abnormality']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0001943',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'MPheno.ontology',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'MP:0005388',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'respiratory system phenotype',
#      'iri': 'http://purl.obolibrary.org/obo/MP_0005388',
#      'label': 'respiratory system phenotype'}],
#    'overview': '(1709066)--[subClassOf,130265430]-->(2572968)--[subClassOf,127138940]-->(749956)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'Phenotype',
#       'cliqueLeader'],
#      'category': 'Phenotype',
#      'definition': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://purl.obolibrary.org/obo/IAO_0000115': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://www.geneontology.org/formats/oboInOwl#created_by': 'doelkens',
#      'http://www.geneontology.org/formats/oboInOwl#creation_date': '2011-06-06T06:38:53Z',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['SNOMEDCT_US:46621007',
#       'UMLS:C0004144',
#       'MSH:D001261'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Pulmonary atelectasis',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0100750',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Atelectasis',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0100750',
#      'label': 'Atelectasis',
#      'synonym': 'Pulmonary atelectasis'},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0001177',
#      'equivalentOriginalNodeTarget': 'http://purl.obolibrary.org/obo/MP_0002327',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': 'UMLS:C4025677',
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Functional respiratory abnormality',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795',
#      'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0002795',
#      'label': 'Functional respiratory abnormality',
#      'synonym': ['Respiratory problem', 'Functional respiratory abnormality']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0002133',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'MPheno.ontology',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'MP:0005388',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'respiratory system phenotype',
#      'iri': 'http://purl.obolibrary.org/obo/MP_0005388',
#      'label': 'respiratory system phenotype'}],
#    'overview': '(1709066)--[subClassOf,130265430]-->(2572968)--[subClassOf,127139337]-->(749956)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'Phenotype',
#       'cliqueLeader'],
#      'category': 'Phenotype',
#      'definition': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://purl.obolibrary.org/obo/IAO_0000115': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://www.geneontology.org/formats/oboInOwl#created_by': 'doelkens',
#      'http://www.geneontology.org/formats/oboInOwl#creation_date': '2011-06-06T06:38:53Z',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['SNOMEDCT_US:46621007',
#       'UMLS:C0004144',
#       'MSH:D001261'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Pulmonary atelectasis',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0100750',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Atelectasis',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0100750',
#      'label': 'Atelectasis',
#      'synonym': 'Pulmonary atelectasis'},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0001177',
#      'equivalentOriginalNodeTarget': 'http://purl.obolibrary.org/obo/MP_0002327',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': 'UMLS:C4025677',
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Functional respiratory abnormality',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795',
#      'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0002795',
#      'label': 'Functional respiratory abnormality',
#      'synonym': ['Respiratory problem', 'Functional respiratory abnormality']},
#     {'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'MPheno.ontology',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'MP:0005388',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'respiratory system phenotype',
#      'iri': 'http://purl.obolibrary.org/obo/MP_0005388',
#      'label': 'respiratory system phenotype'}],
#    'overview': '(1709066)--[subClassOf,130265430]-->(2572968)--[subClassOf,23413018]-->(749956)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'Phenotype',
#       'cliqueLeader'],
#      'category': 'Phenotype',
#      'definition': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://purl.obolibrary.org/obo/IAO_0000115': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://www.geneontology.org/formats/oboInOwl#created_by': 'doelkens',
#      'http://www.geneontology.org/formats/oboInOwl#creation_date': '2011-06-06T06:38:53Z',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['SNOMEDCT_US:46621007',
#       'UMLS:C0004144',
#       'MSH:D001261'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Pulmonary atelectasis',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0100750',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Atelectasis',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0100750',
#      'label': 'Atelectasis',
#      'synonym': 'Pulmonary atelectasis'},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0001177',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': 'UMLS:C4025677',
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Functional respiratory abnormality',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795',
#      'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0002795',
#      'label': 'Functional respiratory abnormality',
#      'synonym': ['Respiratory problem', 'Functional respiratory abnormality']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0002327',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'MPheno.ontology',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'MP:0005388',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'respiratory system phenotype',
#      'iri': 'http://purl.obolibrary.org/obo/MP_0005388',
#      'label': 'respiratory system phenotype'}],
#    'overview': '(1709066)--[subClassOf,130265434]-->(2572968)--[subClassOf,127139203]-->(749956)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'Phenotype',
#       'cliqueLeader'],
#      'category': 'Phenotype',
#      'definition': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://purl.obolibrary.org/obo/IAO_0000115': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://www.geneontology.org/formats/oboInOwl#created_by': 'doelkens',
#      'http://www.geneontology.org/formats/oboInOwl#creation_date': '2011-06-06T06:38:53Z',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['SNOMEDCT_US:46621007',
#       'UMLS:C0004144',
#       'MSH:D001261'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Pulmonary atelectasis',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0100750',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Atelectasis',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0100750',
#      'label': 'Atelectasis',
#      'synonym': 'Pulmonary atelectasis'},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0001177',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': 'UMLS:C4025677',
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Functional respiratory abnormality',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795',
#      'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0002795',
#      'label': 'Functional respiratory abnormality',
#      'synonym': ['Respiratory problem', 'Functional respiratory abnormality']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0001943',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'MPheno.ontology',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'MP:0005388',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'respiratory system phenotype',
#      'iri': 'http://purl.obolibrary.org/obo/MP_0005388',
#      'label': 'respiratory system phenotype'}],
#    'overview': '(1709066)--[subClassOf,130265434]-->(2572968)--[subClassOf,127138940]-->(749956)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'Phenotype',
#       'cliqueLeader'],
#      'category': 'Phenotype',
#      'definition': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://purl.obolibrary.org/obo/IAO_0000115': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://www.geneontology.org/formats/oboInOwl#created_by': 'doelkens',
#      'http://www.geneontology.org/formats/oboInOwl#creation_date': '2011-06-06T06:38:53Z',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['SNOMEDCT_US:46621007',
#       'UMLS:C0004144',
#       'MSH:D001261'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Pulmonary atelectasis',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0100750',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Atelectasis',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0100750',
#      'label': 'Atelectasis',
#      'synonym': 'Pulmonary atelectasis'},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0001177',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': 'UMLS:C4025677',
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Functional respiratory abnormality',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795',
#      'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0002795',
#      'label': 'Functional respiratory abnormality',
#      'synonym': ['Respiratory problem', 'Functional respiratory abnormality']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0002133',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'MPheno.ontology',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'MP:0005388',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'respiratory system phenotype',
#      'iri': 'http://purl.obolibrary.org/obo/MP_0005388',
#      'label': 'respiratory system phenotype'}],
#    'overview': '(1709066)--[subClassOf,130265434]-->(2572968)--[subClassOf,127139337]-->(749956)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'Phenotype',
#       'cliqueLeader'],
#      'category': 'Phenotype',
#      'definition': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://purl.obolibrary.org/obo/IAO_0000115': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://www.geneontology.org/formats/oboInOwl#created_by': 'doelkens',
#      'http://www.geneontology.org/formats/oboInOwl#creation_date': '2011-06-06T06:38:53Z',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['SNOMEDCT_US:46621007',
#       'UMLS:C0004144',
#       'MSH:D001261'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Pulmonary atelectasis',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0100750',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Atelectasis',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0100750',
#      'label': 'Atelectasis',
#      'synonym': 'Pulmonary atelectasis'},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0001177',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': 'UMLS:C4025677',
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Functional respiratory abnormality',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795',
#      'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0002795',
#      'label': 'Functional respiratory abnormality',
#      'synonym': ['Respiratory problem', 'Functional respiratory abnormality']},
#     {'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'MPheno.ontology',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'MP:0005388',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'respiratory system phenotype',
#      'iri': 'http://purl.obolibrary.org/obo/MP_0005388',
#      'label': 'respiratory system phenotype'}],
#    'overview': '(1709066)--[subClassOf,130265434]-->(2572968)--[subClassOf,23413018]-->(749956)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'Phenotype',
#       'cliqueLeader'],
#      'category': 'Phenotype',
#      'definition': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://purl.obolibrary.org/obo/IAO_0000115': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://www.geneontology.org/formats/oboInOwl#created_by': 'doelkens',
#      'http://www.geneontology.org/formats/oboInOwl#creation_date': '2011-06-06T06:38:53Z',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['SNOMEDCT_US:46621007',
#       'UMLS:C0004144',
#       'MSH:D001261'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Pulmonary atelectasis',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0100750',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Atelectasis',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0100750',
#      'label': 'Atelectasis',
#      'synonym': 'Pulmonary atelectasis'},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0001177',
#      'equivalentOriginalNodeTarget': 'http://purl.obolibrary.org/obo/MP_0002133',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': 'UMLS:C4025677',
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Functional respiratory abnormality',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795',
#      'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0002795',
#      'label': 'Functional respiratory abnormality',
#      'synonym': ['Respiratory problem', 'Functional respiratory abnormality']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0002327',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'MPheno.ontology',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'MP:0005388',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'respiratory system phenotype',
#      'iri': 'http://purl.obolibrary.org/obo/MP_0005388',
#      'label': 'respiratory system phenotype'}],
#    'overview': '(1709066)--[subClassOf,130265432]-->(2572968)--[subClassOf,127139203]-->(749956)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'Phenotype',
#       'cliqueLeader'],
#      'category': 'Phenotype',
#      'definition': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://purl.obolibrary.org/obo/IAO_0000115': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://www.geneontology.org/formats/oboInOwl#created_by': 'doelkens',
#      'http://www.geneontology.org/formats/oboInOwl#creation_date': '2011-06-06T06:38:53Z',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['SNOMEDCT_US:46621007',
#       'UMLS:C0004144',
#       'MSH:D001261'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Pulmonary atelectasis',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0100750',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Atelectasis',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0100750',
#      'label': 'Atelectasis',
#      'synonym': 'Pulmonary atelectasis'},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0001177',
#      'equivalentOriginalNodeTarget': 'http://purl.obolibrary.org/obo/MP_0002133',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': 'UMLS:C4025677',
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Functional respiratory abnormality',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795',
#      'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0002795',
#      'label': 'Functional respiratory abnormality',
#      'synonym': ['Respiratory problem', 'Functional respiratory abnormality']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0001943',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'MPheno.ontology',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'MP:0005388',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'respiratory system phenotype',
#      'iri': 'http://purl.obolibrary.org/obo/MP_0005388',
#      'label': 'respiratory system phenotype'}],
#    'overview': '(1709066)--[subClassOf,130265432]-->(2572968)--[subClassOf,127138940]-->(749956)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'Phenotype',
#       'cliqueLeader'],
#      'category': 'Phenotype',
#      'definition': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://purl.obolibrary.org/obo/IAO_0000115': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://www.geneontology.org/formats/oboInOwl#created_by': 'doelkens',
#      'http://www.geneontology.org/formats/oboInOwl#creation_date': '2011-06-06T06:38:53Z',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['SNOMEDCT_US:46621007',
#       'UMLS:C0004144',
#       'MSH:D001261'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Pulmonary atelectasis',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0100750',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Atelectasis',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0100750',
#      'label': 'Atelectasis',
#      'synonym': 'Pulmonary atelectasis'},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0001177',
#      'equivalentOriginalNodeTarget': 'http://purl.obolibrary.org/obo/MP_0002133',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': 'UMLS:C4025677',
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Functional respiratory abnormality',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795',
#      'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0002795',
#      'label': 'Functional respiratory abnormality',
#      'synonym': ['Respiratory problem', 'Functional respiratory abnormality']},
# ...
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795',
#      'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0002795',
#      'label': 'Functional respiratory abnormality',
#      'synonym': ['Respiratory problem', 'Functional respiratory abnormality']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0002133',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'MPheno.ontology',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'MP:0005388',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'respiratory system phenotype',
#      'iri': 'http://purl.obolibrary.org/obo/MP_0005388',
#      'label': 'respiratory system phenotype'}],
#    'overview': '(1709066)--[subClassOf,127139389]-->(2572968)--[subClassOf,127139337]-->(749956)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'Phenotype',
#       'cliqueLeader'],
#      'category': 'Phenotype',
#      'definition': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://purl.obolibrary.org/obo/IAO_0000115': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://www.geneontology.org/formats/oboInOwl#created_by': 'doelkens',
#      'http://www.geneontology.org/formats/oboInOwl#creation_date': '2011-06-06T06:38:53Z',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['SNOMEDCT_US:46621007',
#       'UMLS:C0004144',
#       'MSH:D001261'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Pulmonary atelectasis',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0100750',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Atelectasis',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0100750',
#      'label': 'Atelectasis',
#      'synonym': 'Pulmonary atelectasis'},
#     {'equivalentOriginalNodeTarget': 'http://purl.obolibrary.org/obo/MP_0002133',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': 'UMLS:C4025677',
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Functional respiratory abnormality',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795',
#      'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0002795',
#      'label': 'Functional respiratory abnormality',
#      'synonym': ['Respiratory problem', 'Functional respiratory abnormality']},
#     {'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'MPheno.ontology',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'MP:0005388',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'respiratory system phenotype',
#      'iri': 'http://purl.obolibrary.org/obo/MP_0005388',
#      'label': 'respiratory system phenotype'}],
#    'overview': '(1709066)--[subClassOf,127139389]-->(2572968)--[subClassOf,23413018]-->(749956)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'Phenotype',
#       'cliqueLeader'],
#      'category': 'Phenotype',
#      'definition': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://purl.obolibrary.org/obo/IAO_0000115': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://www.geneontology.org/formats/oboInOwl#created_by': 'doelkens',
#      'http://www.geneontology.org/formats/oboInOwl#creation_date': '2011-06-06T06:38:53Z',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['SNOMEDCT_US:46621007',
#       'UMLS:C0004144',
#       'MSH:D001261'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Pulmonary atelectasis',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0100750',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Atelectasis',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0100750',
#      'label': 'Atelectasis',
#      'synonym': 'Pulmonary atelectasis'},
#     {'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': 'UMLS:C4025677',
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Functional respiratory abnormality',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795',
#      'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0002795',
#      'label': 'Functional respiratory abnormality',
#      'synonym': ['Respiratory problem', 'Functional respiratory abnormality']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0002327',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'MPheno.ontology',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'MP:0005388',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'respiratory system phenotype',
#      'iri': 'http://purl.obolibrary.org/obo/MP_0005388',
#      'label': 'respiratory system phenotype'}],
#    'overview': '(1709066)--[subClassOf,24512866]-->(2572968)--[subClassOf,127139203]-->(749956)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'Phenotype',
#       'cliqueLeader'],
#      'category': 'Phenotype',
#      'definition': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://purl.obolibrary.org/obo/IAO_0000115': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://www.geneontology.org/formats/oboInOwl#created_by': 'doelkens',
#      'http://www.geneontology.org/formats/oboInOwl#creation_date': '2011-06-06T06:38:53Z',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['SNOMEDCT_US:46621007',
#       'UMLS:C0004144',
#       'MSH:D001261'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Pulmonary atelectasis',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0100750',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Atelectasis',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0100750',
#      'label': 'Atelectasis',
#      'synonym': 'Pulmonary atelectasis'},
#     {'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': 'UMLS:C4025677',
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Functional respiratory abnormality',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795',
#      'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0002795',
#      'label': 'Functional respiratory abnormality',
#      'synonym': ['Respiratory problem', 'Functional respiratory abnormality']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0001943',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'MPheno.ontology',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'MP:0005388',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'respiratory system phenotype',
#      'iri': 'http://purl.obolibrary.org/obo/MP_0005388',
#      'label': 'respiratory system phenotype'}],
#    'overview': '(1709066)--[subClassOf,24512866]-->(2572968)--[subClassOf,127138940]-->(749956)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'Phenotype',
#       'cliqueLeader'],
#      'category': 'Phenotype',
#      'definition': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://purl.obolibrary.org/obo/IAO_0000115': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://www.geneontology.org/formats/oboInOwl#created_by': 'doelkens',
#      'http://www.geneontology.org/formats/oboInOwl#creation_date': '2011-06-06T06:38:53Z',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['SNOMEDCT_US:46621007',
#       'UMLS:C0004144',
#       'MSH:D001261'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Pulmonary atelectasis',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0100750',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Atelectasis',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0100750',
#      'label': 'Atelectasis',
#      'synonym': 'Pulmonary atelectasis'},
#     {'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': 'UMLS:C4025677',
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Functional respiratory abnormality',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795',
#      'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0002795',
#      'label': 'Functional respiratory abnormality',
#      'synonym': ['Respiratory problem', 'Functional respiratory abnormality']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/MP_0002133',
#      'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'MPheno.ontology',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'MP:0005388',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'respiratory system phenotype',
#      'iri': 'http://purl.obolibrary.org/obo/MP_0005388',
#      'label': 'respiratory system phenotype'}],
#    'overview': '(1709066)--[subClassOf,24512866]-->(2572968)--[subClassOf,127139337]-->(749956)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'Phenotype',
#       'cliqueLeader'],
#      'category': 'Phenotype',
#      'definition': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://purl.obolibrary.org/obo/IAO_0000115': 'Collapse of part of a lung associated with absence of inflation (air) of that part.',
#      'http://www.geneontology.org/formats/oboInOwl#created_by': 'doelkens',
#      'http://www.geneontology.org/formats/oboInOwl#creation_date': '2011-06-06T06:38:53Z',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['SNOMEDCT_US:46621007',
#       'UMLS:C0004144',
#       'MSH:D001261'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Pulmonary atelectasis',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0100750',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Atelectasis',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0100750',
#      'label': 'Atelectasis',
#      'synonym': 'Pulmonary atelectasis'},
#     {'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': 'UMLS:C4025677',
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'Functional respiratory abnormality',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'human_phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': 'Respiratory problem',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'HP:0002795',
#      'http://www.w3.org/2000/01/rdf-schema#comment': 'This category describes not-primarily structural lesions.',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'Functional respiratory abnormality',
#      'iri': 'http://purl.obolibrary.org/obo/HP_0002795',
#      'label': 'Functional respiratory abnormality',
#      'synonym': ['Respiratory problem', 'Functional respiratory abnormality']},
#     {'isDefinedBy': 'http://purl.obolibrary.org/obo/upheno/monarch.owl',
#      'lbl': 'subClassOf',
#      'type': 'subClassOf'},
#     {'Neo4jLabel': ['Class', 'Node', 'Phenotype', 'cliqueLeader'],
#      'category': 'Phenotype',
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'MPheno.ontology',
#      'http://www.geneontology.org/formats/oboInOwl#id': 'MP:0005388',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'respiratory system phenotype',
#      'iri': 'http://purl.obolibrary.org/obo/MP_0005388',
#      'label': 'respiratory system phenotype'}],
#    'overview': '(1709066)--[subClassOf,24512866]-->(2572968)--[subClassOf,23413018]-->(749956)'}}]

# %% [markdown]
# ##### Design the experiment

# %%
# my experiment
# api address
api = 'https://scigraph-data.monarchinitiative.org/scigraph'
endpoint = '/cypher/execute.json'

# nodes
# iris obtained through /cypher/execute and 
# query=START n=node:node_auto_index(iri='CHEBI:506227') match (n) return n
s1 = 'OMIM_615273' #'OMIM:615273' -> obo + s1
s2 = '55768' #'NCBIGene:55768' -> ncbigene + geneid
e1 = '358' #'NCBIGene:358'
e2 = '11826' #'NCBIGene:11826'
e3 = 'CHEBI_506227' #'CHEBI:506227' -> obo + e3
md = '15'

# %%
# hypothesis for s1->s2 
# cypher query - all shortest paths [allShortestPaths()] - DIRECTED SEARCH

obo = 'http://purl.obolibrary.org/obo/'
ncbigene = 'http://www.ncbi.nlm.nih.gov/gene/'
s = obo + s1 
r = ''
md = '15'
e = ncbigene + s2 
query='''
      MATCH path = allShortestPaths(
       (start:Node{iri:"'''+s+'''"})-['''+r+'''*..'''+md+''']->(end:Node{iri:"'''+e+'''"})
      )
      RETURN path
'''

# api call 
data = {
    'cypherQuery':query,
    'limit':1000
}
r = requests.get('{}{}'.format(api,endpoint), params=data)
r.headers
r.status_code
#print('Path-overview: {}'.format(r.json()[0]['path']['overview']))
#print('Path-details: {}'.format(r.json()[0]['path']['details']))
print('number of paths: {}'.format(len(r.json())))
n1_to_n2 = r.json()
r.json()
# Out:
# number of paths: 1
# [{'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'disease',
#       'cliqueLeader'],
#      'category': 'disease',
#      'definition': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://purl.obolibrary.org/obo/IAO_0000115': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['DOID:0060728',
#       'ICD10:E77.8',
#       'OMIM:615273',
#       'Orphanet:404454',
#       'UMLS:C3808991'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'congenital disorder of deglycosylation'],
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'mondo',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'Cdg Iv',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Cdg Iv, Formerly'],
#      'http://www.geneontology.org/formats/oboInOwl#id': 'OMIM:615273',
#      'http://www.w3.org/2000/01/rdf-schema#label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'iri': 'http://purl.obolibrary.org/obo/OMIM_615273',
#      'label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'synonym': ['CDDG',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'Cdg Iv',
#       'Cdg Iv, Formerly',
#       'congenital disorder of deglycosylation']},
#     {'iri': 'http://purl.obolibrary.org/obo/IAO_0000142',
#      'isDefinedBy': 'https://data.monarchinitiative.org/ttl/omim.ttl',
#      'lbl': 'mentions',
#      'type': 'http://purl.obolibrary.org/obo/IAO_0000142'},
#     {'Neo4jLabel': ['NamedIndividual', 'Node', 'publication', 'cliqueLeader'],
#      'category': 'publication',
#      'iri': 'http://www.ncbi.nlm.nih.gov/pubmed/24651605'},
#     {'iri': 'http://purl.obolibrary.org/obo/IAO_0000136',
#      'isDefinedBy': 'https://data.monarchinitiative.org/ttl/ncbigene.ttl',
#      'lbl': 'is_about',
#      'type': 'http://purl.obolibrary.org/obo/IAO_0000136'},
#     {'Neo4jLabel': ['Class',
#       'Node',
#       'gene',
#       'sequence feature',
#       'cliqueLeader'],
#      'category': ['gene', 'sequence feature'],
#      'http://purl.org/dc/elements/1.1/description': ['N-glycanase 1',
#       'Peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'N-glycanase 1',
#       'FLJ12409'],
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['peptide:N-glycanase',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'PNG1',
#       'CDDG'],
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NGLY1',
#      'iri': 'http://www.ncbi.nlm.nih.gov/gene/55768',
#      'label': 'NGLY1',
#      'synonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'peptide:N-glycanase',
#       'N-glycanase 1',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'CDDG',
#       'FLJ12409']}],
#    'overview': '(179791)--[http://purl.obolibrary.org/obo/IAO_0000142,3304816]-->(256641)--[http://purl.obolibrary.org/obo/IAO_0000136,53913466]-->(83497)'}}]

# %%
# hypothesis for s2->s1? i get the same results than before? NO
# cypher query - all shortest paths [allShortestPaths()] - DIRECTED SEARCH

obo = 'http://purl.obolibrary.org/obo/'
ncbigene = 'http://www.ncbi.nlm.nih.gov/gene/'
s = ncbigene + s2 
r = ''
md = '15'
e = obo + s1 
query='''
      MATCH path = allShortestPaths(
       (start:Node{iri:"'''+s+'''"})-['''+r+'''*..'''+md+''']->(end:Node{iri:"'''+e+'''"})
      )
      RETURN path
'''

# api call 
data = {
    'cypherQuery':query,
    'limit':1000
}
r = requests.get('{}{}'.format(api,endpoint), params=data)
r.headers
r.status_code
#print('Path-overview: {}'.format(r.json()[0]['path']['overview']))
#print('Path-details: {}'.format(r.json()[0]['path']['details']))
print('number of paths: {}'.format(len(r.json())))
n2_to_n1 = r.json()
r.json()
# Out:
# number of paths: 5
# [{'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'gene',
#       'sequence feature',
#       'cliqueLeader'],
#      'category': ['gene', 'sequence feature'],
#      'http://purl.org/dc/elements/1.1/description': ['N-glycanase 1',
#       'Peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'N-glycanase 1',
#       'FLJ12409'],
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['peptide:N-glycanase',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'PNG1',
#       'CDDG'],
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NGLY1',
#      'iri': 'http://www.ncbi.nlm.nih.gov/gene/55768',
#      'label': 'NGLY1',
#      'synonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'peptide:N-glycanase',
#       'N-glycanase 1',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'CDDG',
#       'FLJ12409']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/OMIM_610661',
#      'iri': 'http://purl.obolibrary.org/obo/IAO_0000142',
#      'isDefinedBy': 'https://data.monarchinitiative.org/ttl/omim.ttl',
#      'lbl': 'mentions',
#      'type': 'http://purl.obolibrary.org/obo/IAO_0000142'},
#     {'Neo4jLabel': ['NamedIndividual', 'Node', 'publication', 'cliqueLeader'],
#      'category': 'publication',
#      'iri': 'http://www.ncbi.nlm.nih.gov/pubmed/24651605'},
#     {'iri': 'http://purl.obolibrary.org/obo/IAO_0000142',
#      'isDefinedBy': 'http://data.monarchinitiative.org/ttl/coriell.ttl',
#      'lbl': 'mentions',
#      'type': 'http://purl.obolibrary.org/obo/IAO_0000142'},
#     {'Neo4jLabel': ['Node', 'cell line', 'cliqueLeader'],
#      'category': 'cell line',
#      'http://purl.org/dc/elements/1.1/description': "Clinically affected; diagnosed at 3 years 4 months  of age; onset of symptoms from birth; 2nd trimester pregnancy positive screen for Smith-Lemli-Opitz syndrome and trisomy 18: alpha-fetoprotein (AFP) 1.63 multiple of the median (MoM); unconjugated estriol (uE3) 0.26 MoM; human chorionic gonadotrophin 0.54 MoM; inhibin 1.02 MoM; amniocentesis karyotype was normal; born by Cesarean section at term due to concerning fetal heart tracing; monitored in NICU due to poor feeding and lethargy; neonatal period: hyperbilirubinemia treated with phototherapy; elevated liver transaminases and transient thrombocytopenia; in  infancy: global developmental delay; acquired macrocephaly; bilateral exotropia; hypotonia; constipation; at 1 year: no tears while crying; but enough to keep eyes moist; once-daily staring spells for about 15 seconds each; at 17 months: developed extrapyramidal movement disorder with asynchronous myoclonic jerks of the limbs and shoulders and subtle choreoathetotic movements of the hands and fingers; 4 years of age: ambulated unassisted with unsteady gait; communicated with use of vocalizations; gestures; and an assistive communication device; donor subject noted to have: small hands/feet; chalazions; strabismus; ocular apraxia; auditory brainstem response abnormalities;   elevated blood lactate levels (3.7-7.5 mmol/l in infancy; 6.4 mmol/l at 21 months; 6.7 mmol/l at 31 months; 3.7 mmol/l at 32 months); liver storage or vacuolization; MRI results: mild global reduction in cerebral hemisphere volume and thin corpus callosum and anterior commissure noted in MRI at 17 months; MRS normal; whole genome sequencing (Sanger; Next-Generation Sequencing; hg19) performed at two different institutions revealed the donor subject is compound heterozygous for two mutations in the NGLY1 gene: a 3-base pair in-frame TTC> deletion beginning at position 3:25775416 (c.1205_1207del; p.402del) also identified in the proband��s mother (not in repository)  and a stop-gain mutation at position 3:25761670 (c.1570C>T; p.R542X) also identified in proband��s father (not in repository); medications/supplements: N-acetylcysteine; Periactin; Miralax; Cocoavia; Theratears eye drops; Refresh PM ointment; children's probiotic; Albuterol inhaler; management: physical therapy; occupational therapy; and speech language therapy; assistive devices: orthotics and communication/learning device. [Donor subject is referenced as Patient 3 in publication by Enns et al. 2014 - PMID 24651605.]",
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NIGMS-GM25990',
#      'iri': 'https://catalog.coriell.org/0/Sections/Search/Sample_Detail.aspx?Ref=GM25990',
#      'label': 'NIGMS-GM25990'},
#     {'iri': 'http://purl.obolibrary.org/obo/RO_0003301',
#      'isDefinedBy': 'http://data.monarchinitiative.org/ttl/coriell.ttl',
#      'lbl': 'is model of',
#      'type': 'http://purl.obolibrary.org/obo/RO_0003301'},
#     {'Neo4jLabel': ['Class', 'Node', 'disease', 'cliqueLeader'],
#      'category': 'disease',
#      'definition': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://purl.obolibrary.org/obo/IAO_0000115': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['DOID:0060728',
#       'ICD10:E77.8',
#       'OMIM:615273',
#       'Orphanet:404454',
#       'UMLS:C3808991'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'congenital disorder of deglycosylation'],
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'mondo',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'Cdg Iv',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Cdg Iv, Formerly'],
#      'http://www.geneontology.org/formats/oboInOwl#id': 'OMIM:615273',
#      'http://www.w3.org/2000/01/rdf-schema#label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'iri': 'http://purl.obolibrary.org/obo/OMIM_615273',
#      'label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'synonym': ['CDDG',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'Cdg Iv',
#       'Cdg Iv, Formerly',
#       'congenital disorder of deglycosylation']}],
#    'overview': '(83497)--[http://purl.obolibrary.org/obo/IAO_0000142,123017819]-->(256641)--[http://purl.obolibrary.org/obo/IAO_0000142,296360]-->(232712)--[http://purl.obolibrary.org/obo/RO_0003301,437917]-->(179791)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'gene',
#       'sequence feature',
#       'cliqueLeader'],
#      'category': ['gene', 'sequence feature'],
#      'http://purl.org/dc/elements/1.1/description': ['N-glycanase 1',
#       'Peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'N-glycanase 1',
#       'FLJ12409'],
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['peptide:N-glycanase',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'PNG1',
#       'CDDG'],
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NGLY1',
#      'iri': 'http://www.ncbi.nlm.nih.gov/gene/55768',
#      'label': 'NGLY1',
#      'synonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'peptide:N-glycanase',
#       'N-glycanase 1',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'CDDG',
#       'FLJ12409']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/OMIM_610661',
#      'iri': 'http://purl.obolibrary.org/obo/IAO_0000142',
#      'isDefinedBy': 'https://data.monarchinitiative.org/ttl/omim.ttl',
#      'lbl': 'mentions',
#      'type': 'http://purl.obolibrary.org/obo/IAO_0000142'},
#     {'Neo4jLabel': ['NamedIndividual', 'Node', 'publication', 'cliqueLeader'],
#      'category': 'publication',
#      'iri': 'http://www.ncbi.nlm.nih.gov/pubmed/24651605'},
#     {'iri': 'http://purl.obolibrary.org/obo/IAO_0000142',
#      'isDefinedBy': 'http://data.monarchinitiative.org/ttl/coriell.ttl',
#      'lbl': 'mentions',
#      'type': 'http://purl.obolibrary.org/obo/IAO_0000142'},
#     {'Neo4jLabel': ['Node', 'cell line', 'cliqueLeader'],
#      'category': 'cell line',
#      'http://purl.org/dc/elements/1.1/description': 'Clinically affected; onset of symptoms at birth; diagnosed with N-glycanase deficiency at 4 years of age; symptoms at birth: neonatal jaundice; global developmental delay; hypotonia; involuntary movements (athetosis involving the trunk and extremities and constant lip smacking and pursing); intractable multifocal epilepsy (consisting of myoclonic seizures; drop attacks; and staring or tonic episodes); abnormal liver function; At 15 months of age subject showed regression of motor development; At 4 years of age subject was noted to have cortical vision impairment; congenital alacrima (absence of tears); corneal ulcerations with scarring; At 5 years of age subject continues to have movement disorder; able to sit up; able to reach for objects and transfer them from hand to hand; never developed speech; abnormal EEG; decreased deep tendon reflexes; seizures; chalazions; elevated liver transaminases; elevated AFP; liver fibrosis; liver storage or vacuolization; constipation; peripheral neuropathy; small hands and feet; brain MRI at 8 months was normal but brain MRI at 15 months detected prominent perivascular spaces with surrounding gliosis in periatrial white matter and mildly delayed myelination; liver biopsy showed inflammatory changes with an amorphous substance in the cytoplasm; abnormal urine oligosaccharides with keratan sulfate; heparan sulfate; and chondroitin sulfate; testing for congenital disorders of glycosylation was normal by transferrin isoelectric focusing and N-glycan analysis; biochemical testing by Western blot showed no detectable NGLY1; molecular genetic testing by whole exome sequencing (WES) revealed compound heterozygous mutations in the NGLY1 gene:  maternally inherited c.1891delC (p.Q631fs - frameshift mutation in exon 12) and paternally inherited c.1201A>T (p.R401X - nonsense mutation in exon 8); treatment and management includes: medications; physical therapy; occupational therapy; and speech language therapy; assistive devices: wheelchair; braces; orthotics; communication/learning device; mother (GM25341); father (GM25342) . [Subject is referenced as Trio 2 in publication by Needs et al 2012 �� PMID 22581936; and Patient 1 in publication by Enns et al. 2014 - PMID 24651605]',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NIGMS-GM25340',
#      'iri': 'https://catalog.coriell.org/0/Sections/Search/Sample_Detail.aspx?Ref=GM25340',
#      'label': 'NIGMS-GM25340'},
#     {'iri': 'http://purl.obolibrary.org/obo/RO_0003301',
#      'isDefinedBy': 'http://data.monarchinitiative.org/ttl/coriell.ttl',
#      'lbl': 'is model of',
#      'type': 'http://purl.obolibrary.org/obo/RO_0003301'},
#     {'Neo4jLabel': ['Class', 'Node', 'disease', 'cliqueLeader'],
#      'category': 'disease',
#      'definition': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://purl.obolibrary.org/obo/IAO_0000115': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['DOID:0060728',
#       'ICD10:E77.8',
#       'OMIM:615273',
#       'Orphanet:404454',
#       'UMLS:C3808991'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'congenital disorder of deglycosylation'],
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'mondo',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'Cdg Iv',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Cdg Iv, Formerly'],
#      'http://www.geneontology.org/formats/oboInOwl#id': 'OMIM:615273',
#      'http://www.w3.org/2000/01/rdf-schema#label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'iri': 'http://purl.obolibrary.org/obo/OMIM_615273',
#      'label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'synonym': ['CDDG',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'Cdg Iv',
#       'Cdg Iv, Formerly',
#       'congenital disorder of deglycosylation']}],
#    'overview': '(83497)--[http://purl.obolibrary.org/obo/IAO_0000142,123017819]-->(256641)--[http://purl.obolibrary.org/obo/IAO_0000142,801032]-->(225262)--[http://purl.obolibrary.org/obo/RO_0003301,450253]-->(179791)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'gene',
#       'sequence feature',
#       'cliqueLeader'],
#      'category': ['gene', 'sequence feature'],
#      'http://purl.org/dc/elements/1.1/description': ['N-glycanase 1',
#       'Peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'N-glycanase 1',
#       'FLJ12409'],
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['peptide:N-glycanase',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'PNG1',
#       'CDDG'],
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NGLY1',
#      'iri': 'http://www.ncbi.nlm.nih.gov/gene/55768',
#      'label': 'NGLY1',
#      'synonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'peptide:N-glycanase',
#       'N-glycanase 1',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'CDDG',
#       'FLJ12409']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/OMIM_610661',
#      'iri': 'http://purl.obolibrary.org/obo/IAO_0000142',
#      'isDefinedBy': 'https://data.monarchinitiative.org/ttl/omim.ttl',
#      'lbl': 'mentions',
#      'type': 'http://purl.obolibrary.org/obo/IAO_0000142'},
#     {'Neo4jLabel': ['NamedIndividual', 'Node', 'publication', 'cliqueLeader'],
#      'category': 'publication',
#      'iri': 'http://www.ncbi.nlm.nih.gov/pubmed/24651605'},
#     {'iri': 'http://purl.obolibrary.org/obo/IAO_0000142',
#      'isDefinedBy': 'http://data.monarchinitiative.org/ttl/coriell.ttl',
#      'lbl': 'mentions',
#      'type': 'http://purl.obolibrary.org/obo/IAO_0000142'},
#     {'Neo4jLabel': ['Node', 'cell line', 'cliqueLeader'],
#      'category': 'cell line',
#      'http://purl.org/dc/elements/1.1/description': 'Clinically affected; diagnosed by geneticist at 2 years of age; onset of symptoms at birth; delivered by Cesarean section at 38 weeks gestation when fetal distress was noted on cardiotocography; intrauterine growth restriction; neonatal jaundice; hypotonia;  constipation in infancy; intermittent head flexion at 6 months; global developmental delay; movement disorder; involuntary movements of upper extremities noted at 8 months; seizures - mild myoclonic seizures with head and body flexion occurred and evolved to single; symmetric spasms with bilateral arm extension shortly after 8 months; abnormal sleep patterns characterized by paucity of deep sleep and frequent awakenings; alacrima (abnormal tear production); unilateral ptosis; recurrent episodes of keratoconjunctivitis and poor lid closure during sleep; corneal ulcerations/scarring; chalazions; strabismus; decreased deep tendon reflexes; liver fibrosis; scoliosis; small hands and feet; donor subject learned to crawl and communicate with vocalizations; auditory brainstem response hearing abnormalities detected; electroencephalography (EEG) at 8 months showed generalized polyspike discharges; brain imaging (MRI) at various ages revealed: delayed myelination at 6 months; delayed myelination and supratentorial atrophy secondary to steroid therapy at 10 months; delayed myelination and recovery from supratentorial atrophy at 19 months; elevated blood lactate; elevated liver transaminases (three to four times upper limit of normal) noted in infancy; elevated alpha-fetoprotein; genetic testing revealed homozygous recessive nonsense mutation in NGLY1 gene: c.1201A>T (p.R401X) - found on both the maternal and paternal alleles by Sanger sequencing; management: physical therapy; occupational therapy; speech language therapy; medications: Lamictal; Depakote; epilepsy has been intractable despite many therapeutic trials; described as patient 4 by Enns et al 2014 (PMID 24651605); unaffected carrier mother is GM25348 (lymphoblast).',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NIGMS-GM25347',
#      'iri': 'https://catalog.coriell.org/0/Sections/Search/Sample_Detail.aspx?Ref=GM25347',
#      'label': 'NIGMS-GM25347'},
#     {'iri': 'http://purl.obolibrary.org/obo/RO_0003301',
#      'isDefinedBy': 'http://data.monarchinitiative.org/ttl/coriell.ttl',
#      'lbl': 'is model of',
#      'type': 'http://purl.obolibrary.org/obo/RO_0003301'},
#     {'Neo4jLabel': ['Class', 'Node', 'disease', 'cliqueLeader'],
#      'category': 'disease',
#      'definition': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://purl.obolibrary.org/obo/IAO_0000115': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['DOID:0060728',
#       'ICD10:E77.8',
#       'OMIM:615273',
#       'Orphanet:404454',
#       'UMLS:C3808991'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'congenital disorder of deglycosylation'],
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'mondo',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'Cdg Iv',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Cdg Iv, Formerly'],
#      'http://www.geneontology.org/formats/oboInOwl#id': 'OMIM:615273',
#      'http://www.w3.org/2000/01/rdf-schema#label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'iri': 'http://purl.obolibrary.org/obo/OMIM_615273',
#      'label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'synonym': ['CDDG',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'Cdg Iv',
#       'Cdg Iv, Formerly',
#       'congenital disorder of deglycosylation']}],
#    'overview': '(83497)--[http://purl.obolibrary.org/obo/IAO_0000142,123017819]-->(256641)--[http://purl.obolibrary.org/obo/IAO_0000142,800936]-->(222700)--[http://purl.obolibrary.org/obo/RO_0003301,705195]-->(179791)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'gene',
#       'sequence feature',
#       'cliqueLeader'],
#      'category': ['gene', 'sequence feature'],
#      'http://purl.org/dc/elements/1.1/description': ['N-glycanase 1',
#       'Peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'N-glycanase 1',
#       'FLJ12409'],
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['peptide:N-glycanase',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'PNG1',
#       'CDDG'],
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NGLY1',
#      'iri': 'http://www.ncbi.nlm.nih.gov/gene/55768',
#      'label': 'NGLY1',
#      'synonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'peptide:N-glycanase',
#       'N-glycanase 1',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'CDDG',
#       'FLJ12409']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/OMIM_610661',
#      'iri': 'http://purl.obolibrary.org/obo/IAO_0000142',
#      'isDefinedBy': 'https://data.monarchinitiative.org/ttl/omim.ttl',
#      'lbl': 'mentions',
#      'type': 'http://purl.obolibrary.org/obo/IAO_0000142'},
#     {'Neo4jLabel': ['NamedIndividual', 'Node', 'publication', 'cliqueLeader'],
#      'category': 'publication',
#      'iri': 'http://www.ncbi.nlm.nih.gov/pubmed/24651605'},
#     {'iri': 'http://purl.obolibrary.org/obo/IAO_0000142',
#      'isDefinedBy': 'http://data.monarchinitiative.org/ttl/coriell.ttl',
#      'lbl': 'mentions',
#      'type': 'http://purl.obolibrary.org/obo/IAO_0000142'},
#     {'Neo4jLabel': ['Node', 'cell line', 'cliqueLeader'],
#      'category': 'cell line',
#      'http://purl.org/dc/elements/1.1/description': 'Clinically affected; born at 39-weeks via Cesarean section due to intrauterine growth restriction (IUGR) and abnormal-appearing placenta on ultrasound; at 4 months: hypotonia; global developmental delay; elevated liver transaminases; at 4 years: slight intention tremor and frequent involuntary movements of neck; hands; and arm (movement disorder); at 5 years: ocular apraxia; distal tapering of hands and feet; diminished deep tendon reflexes; cortical vision impairment;  alacrima; dry eyes; microcephaly; liver storage/vacuolization; constipation; scoliosis; peripheral neuropathy (determined by nerve conduction velocity test); cognitive; motor; and speech impairment; MRI at 4 months: slightly dilated lateral ventricles; abnormal EEG; elevated blood lactate levels at 4 months were 3.9 mmol/l and at 1 year were 2.7 mmol/l (normal <2.2 mmol/l);whole exome sequencing (WES) confirmed by Sanger sequencing revealed a homozygous c.1370dupG (R458fs) mutation in exon 9 of NGLY1 gene; incidental WES findings showed subject is also heterozygous for the following genetic variants of unknown clinical significance: c.2872A>G (p.T958A) in exon 17 of HCFC1 gene; and other variants of possible phenotypic overlap: c.175C>T (p.R59X) in exon 3 of GNE gene; c.5636G>A (p.R1879Q) in exon 20 of ARID1A gene; c.1456C>T (p.H188Y) in exon 13 of PSAP gene; c.1099C>G (p.H387D) in exon 11 of ALG1 gene; c.670G>A (p.A224T) in exon 8 of GAMT gene; c.1432G>A (p.V478I) in exon 11 of ZC3H14 gene; c.983A>G (p.Q328R) in exon 9 of CHKB gene; and c.119A>G (p.D40G) in exon 1 of ALDH3A2; c.2872A>G (p.T958A) in exon 17 of the HCFC1 gene; assistive devices: speech-generating device and walker; parents are consanguineous; mother (GM25390) and father (GM25391) are both unaffected carriers of a c.1370dupG (R458fs) mutation in exon 9 of the NGLY1 gene. [see Patient 2 in publication by Enns et al. 2014 - PMID 24651605].',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NIGMS-GM25389',
#      'iri': 'https://catalog.coriell.org/0/Sections/Search/Sample_Detail.aspx?Ref=GM25389',
#      'label': 'NIGMS-GM25389'},
#     {'iri': 'http://purl.obolibrary.org/obo/RO_0003301',
#      'isDefinedBy': 'http://data.monarchinitiative.org/ttl/coriell.ttl',
#      'lbl': 'is model of',
#      'type': 'http://purl.obolibrary.org/obo/RO_0003301'},
#     {'Neo4jLabel': ['Class', 'Node', 'disease', 'cliqueLeader'],
#      'category': 'disease',
#      'definition': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://purl.obolibrary.org/obo/IAO_0000115': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['DOID:0060728',
#       'ICD10:E77.8',
#       'OMIM:615273',
#       'Orphanet:404454',
#       'UMLS:C3808991'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'congenital disorder of deglycosylation'],
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'mondo',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'Cdg Iv',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Cdg Iv, Formerly'],
#      'http://www.geneontology.org/formats/oboInOwl#id': 'OMIM:615273',
#      'http://www.w3.org/2000/01/rdf-schema#label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'iri': 'http://purl.obolibrary.org/obo/OMIM_615273',
#      'label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'synonym': ['CDDG',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'Cdg Iv',
#       'Cdg Iv, Formerly',
#       'congenital disorder of deglycosylation']}],
#    'overview': '(83497)--[http://purl.obolibrary.org/obo/IAO_0000142,123017819]-->(256641)--[http://purl.obolibrary.org/obo/IAO_0000142,804423]-->(241483)--[http://purl.obolibrary.org/obo/RO_0003301,733201]-->(179791)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'gene',
#       'sequence feature',
#       'cliqueLeader'],
#      'category': ['gene', 'sequence feature'],
#      'http://purl.org/dc/elements/1.1/description': ['N-glycanase 1',
#       'Peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'N-glycanase 1',
#       'FLJ12409'],
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['peptide:N-glycanase',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'PNG1',
#       'CDDG'],
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NGLY1',
#      'iri': 'http://www.ncbi.nlm.nih.gov/gene/55768',
#      'label': 'NGLY1',
#      'synonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'peptide:N-glycanase',
#       'N-glycanase 1',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'CDDG',
#       'FLJ12409']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/OMIM_610661',
#      'iri': 'http://purl.obolibrary.org/obo/IAO_0000142',
#      'isDefinedBy': 'https://data.monarchinitiative.org/ttl/omim.ttl',
#      'lbl': 'mentions',
#      'type': 'http://purl.obolibrary.org/obo/IAO_0000142'},
#     {'Neo4jLabel': ['Node', 'publication', 'cliqueLeader'],
#      'category': 'publication',
#      'iri': 'http://www.ncbi.nlm.nih.gov/pubmed/22581936'},
#     {'iri': 'http://purl.obolibrary.org/obo/IAO_0000142',
#      'isDefinedBy': 'http://data.monarchinitiative.org/ttl/coriell.ttl',
#      'lbl': 'mentions',
#      'type': 'http://purl.obolibrary.org/obo/IAO_0000142'},
#     {'Neo4jLabel': ['Node', 'cell line', 'cliqueLeader'],
#      'category': 'cell line',
#      'http://purl.org/dc/elements/1.1/description': 'Clinically affected; onset of symptoms at birth; diagnosed with N-glycanase deficiency at 4 years of age; symptoms at birth: neonatal jaundice; global developmental delay; hypotonia; involuntary movements (athetosis involving the trunk and extremities and constant lip smacking and pursing); intractable multifocal epilepsy (consisting of myoclonic seizures; drop attacks; and staring or tonic episodes); abnormal liver function; At 15 months of age subject showed regression of motor development; At 4 years of age subject was noted to have cortical vision impairment; congenital alacrima (absence of tears); corneal ulcerations with scarring; At 5 years of age subject continues to have movement disorder; able to sit up; able to reach for objects and transfer them from hand to hand; never developed speech; abnormal EEG; decreased deep tendon reflexes; seizures; chalazions; elevated liver transaminases; elevated AFP; liver fibrosis; liver storage or vacuolization; constipation; peripheral neuropathy; small hands and feet; brain MRI at 8 months was normal but brain MRI at 15 months detected prominent perivascular spaces with surrounding gliosis in periatrial white matter and mildly delayed myelination; liver biopsy showed inflammatory changes with an amorphous substance in the cytoplasm; abnormal urine oligosaccharides with keratan sulfate; heparan sulfate; and chondroitin sulfate; testing for congenital disorders of glycosylation was normal by transferrin isoelectric focusing and N-glycan analysis; biochemical testing by Western blot showed no detectable NGLY1; molecular genetic testing by whole exome sequencing (WES) revealed compound heterozygous mutations in the NGLY1 gene:  maternally inherited c.1891delC (p.Q631fs - frameshift mutation in exon 12) and paternally inherited c.1201A>T (p.R401X - nonsense mutation in exon 8); treatment and management includes: medications; physical therapy; occupational therapy; and speech language therapy; assistive devices: wheelchair; braces; orthotics; communication/learning device; mother (GM25341); father (GM25342) . [Subject is referenced as Trio 2 in publication by Needs et al 2012 �� PMID 22581936; and Patient 1 in publication by Enns et al. 2014 - PMID 24651605]',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NIGMS-GM25340',
#      'iri': 'https://catalog.coriell.org/0/Sections/Search/Sample_Detail.aspx?Ref=GM25340',
#      'label': 'NIGMS-GM25340'},
#     {'iri': 'http://purl.obolibrary.org/obo/RO_0003301',
#      'isDefinedBy': 'http://data.monarchinitiative.org/ttl/coriell.ttl',
#      'lbl': 'is model of',
#      'type': 'http://purl.obolibrary.org/obo/RO_0003301'},
#     {'Neo4jLabel': ['Class', 'Node', 'disease', 'cliqueLeader'],
#      'category': 'disease',
#      'definition': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://purl.obolibrary.org/obo/IAO_0000115': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['DOID:0060728',
#       'ICD10:E77.8',
#       'OMIM:615273',
#       'Orphanet:404454',
#       'UMLS:C3808991'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'congenital disorder of deglycosylation'],
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'mondo',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'Cdg Iv',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Cdg Iv, Formerly'],
#      'http://www.geneontology.org/formats/oboInOwl#id': 'OMIM:615273',
#      'http://www.w3.org/2000/01/rdf-schema#label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'iri': 'http://purl.obolibrary.org/obo/OMIM_615273',
#      'label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'synonym': ['CDDG',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'Cdg Iv',
#       'Cdg Iv, Formerly',
#       'congenital disorder of deglycosylation']}],
#    'overview': '(83497)--[http://purl.obolibrary.org/obo/IAO_0000142,123017810]-->(18639)--[http://purl.obolibrary.org/obo/IAO_0000142,528742]-->(225262)--[http://purl.obolibrary.org/obo/RO_0003301,450253]-->(179791)'}}]

# %%
# what would happen if i perform the search using UNDIRECTED path search? 
# do i get the same results than before? NO, i get more paths now without forcing directionality
# do i get the same results for s1-s2 than for s2-s1 now? YES
# hypothesis for s1-s2 
# cypher query - all shortest paths [allShortestPaths()] - UNDIRECTED SEARCH

obo = 'http://purl.obolibrary.org/obo/'
ncbigene = 'http://www.ncbi.nlm.nih.gov/gene/'
s = obo + s1 
r = ''
md = '15'
e = ncbigene + s2 
query='''
      MATCH path = allShortestPaths(
       (start:Node{iri:"'''+s+'''"})-['''+r+'''*..'''+md+''']-(end:Node{iri:"'''+e+'''"})
      )
      RETURN path
'''

# api call 
data = {
    'cypherQuery':query,
    'limit':1000
}
r = requests.get('{}{}'.format(api,endpoint), params=data)
print('number of paths: {}'.format(len(r.json())))
#r.json()

# hypothesis for s2-s1? i get the same results than before? NO
# cypher query - all shortest paths [allShortestPaths()]

obo = 'http://purl.obolibrary.org/obo/'
ncbigene = 'http://www.ncbi.nlm.nih.gov/gene/'
s = ncbigene + s2 
r = ''
md = '15'
e = obo + s1 
query='''
      MATCH path = allShortestPaths(
       (start:Node{iri:"'''+s+'''"})-['''+r+'''*..'''+md+''']-(end:Node{iri:"'''+e+'''"})
      )
      RETURN path
'''

# api call 
data = {
    'cypherQuery':query,
    'limit':1000
}
r = requests.get('{}{}'.format(api,endpoint), params=data)
print('number of paths: {}'.format(len(r.json())))
n1_n2 = r.json()
r.json()
# Out:
# number of paths: 27
# number of paths: 27
# [{'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'gene',
#       'sequence feature',
#       'cliqueLeader'],
#      'category': ['gene', 'sequence feature'],
#      'http://purl.org/dc/elements/1.1/description': ['N-glycanase 1',
#       'Peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'N-glycanase 1',
#       'FLJ12409'],
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['peptide:N-glycanase',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'PNG1',
#       'CDDG'],
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NGLY1',
#      'iri': 'http://www.ncbi.nlm.nih.gov/gene/55768',
#      'label': 'NGLY1',
#      'synonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'peptide:N-glycanase',
#       'N-glycanase 1',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'CDDG',
#       'FLJ12409']},
#     {'iri': 'http://purl.obolibrary.org/obo/IAO_0000136',
#      'isDefinedBy': 'https://data.monarchinitiative.org/ttl/ncbigene.ttl',
#      'lbl': 'is_about',
#      'type': 'http://purl.obolibrary.org/obo/IAO_0000136'},
#     {'Neo4jLabel': ['NamedIndividual', 'Node', 'publication', 'cliqueLeader'],
#      'category': 'publication',
#      'iri': 'http://www.ncbi.nlm.nih.gov/pubmed/24651605'},
#     {'iri': 'http://purl.obolibrary.org/obo/IAO_0000142',
#      'isDefinedBy': 'https://data.monarchinitiative.org/ttl/omim.ttl',
#      'lbl': 'mentions',
#      'type': 'http://purl.obolibrary.org/obo/IAO_0000142'},
#     {'Neo4jLabel': ['Class', 'Node', 'disease', 'cliqueLeader'],
#      'category': 'disease',
#      'definition': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://purl.obolibrary.org/obo/IAO_0000115': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['DOID:0060728',
#       'ICD10:E77.8',
#       'OMIM:615273',
#       'Orphanet:404454',
#       'UMLS:C3808991'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'congenital disorder of deglycosylation'],
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'mondo',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'Cdg Iv',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Cdg Iv, Formerly'],
#      'http://www.geneontology.org/formats/oboInOwl#id': 'OMIM:615273',
#      'http://www.w3.org/2000/01/rdf-schema#label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'iri': 'http://purl.obolibrary.org/obo/OMIM_615273',
#      'label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'synonym': ['CDDG',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'Cdg Iv',
#       'Cdg Iv, Formerly',
#       'congenital disorder of deglycosylation']}],
#    'overview': '(83497)<--[http://purl.obolibrary.org/obo/IAO_0000136,53913466]--(256641)<--[http://purl.obolibrary.org/obo/IAO_0000142,3304816]--(179791)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'gene',
#       'sequence feature',
#       'cliqueLeader'],
#      'category': ['gene', 'sequence feature'],
#      'http://purl.org/dc/elements/1.1/description': ['N-glycanase 1',
#       'Peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'N-glycanase 1',
#       'FLJ12409'],
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['peptide:N-glycanase',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'PNG1',
#       'CDDG'],
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NGLY1',
#      'iri': 'http://www.ncbi.nlm.nih.gov/gene/55768',
#      'label': 'NGLY1',
#      'synonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'peptide:N-glycanase',
#       'N-glycanase 1',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'CDDG',
#       'FLJ12409']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/OMIM_610661',
#      'iri': 'http://purl.obolibrary.org/obo/IAO_0000142',
#      'isDefinedBy': 'https://data.monarchinitiative.org/ttl/omim.ttl',
#      'lbl': 'mentions',
#      'type': 'http://purl.obolibrary.org/obo/IAO_0000142'},
#     {'Neo4jLabel': ['NamedIndividual', 'Node', 'publication', 'cliqueLeader'],
#      'category': 'publication',
#      'iri': 'http://www.ncbi.nlm.nih.gov/pubmed/24651605'},
#     {'iri': 'http://purl.obolibrary.org/obo/IAO_0000142',
#      'isDefinedBy': 'https://data.monarchinitiative.org/ttl/omim.ttl',
#      'lbl': 'mentions',
#      'type': 'http://purl.obolibrary.org/obo/IAO_0000142'},
#     {'Neo4jLabel': ['Class', 'Node', 'disease', 'cliqueLeader'],
#      'category': 'disease',
#      'definition': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://purl.obolibrary.org/obo/IAO_0000115': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['DOID:0060728',
#       'ICD10:E77.8',
#       'OMIM:615273',
#       'Orphanet:404454',
#       'UMLS:C3808991'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'congenital disorder of deglycosylation'],
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'mondo',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'Cdg Iv',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Cdg Iv, Formerly'],
#      'http://www.geneontology.org/formats/oboInOwl#id': 'OMIM:615273',
#      'http://www.w3.org/2000/01/rdf-schema#label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'iri': 'http://purl.obolibrary.org/obo/OMIM_615273',
#      'label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'synonym': ['CDDG',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'Cdg Iv',
#       'Cdg Iv, Formerly',
#       'congenital disorder of deglycosylation']}],
#    'overview': '(83497)--[http://purl.obolibrary.org/obo/IAO_0000142,123017819]-->(256641)<--[http://purl.obolibrary.org/obo/IAO_0000142,3304816]--(179791)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'gene',
#       'sequence feature',
#       'cliqueLeader'],
#      'category': ['gene', 'sequence feature'],
#      'http://purl.org/dc/elements/1.1/description': ['N-glycanase 1',
#       'Peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'N-glycanase 1',
#       'FLJ12409'],
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['peptide:N-glycanase',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'PNG1',
#       'CDDG'],
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NGLY1',
#      'iri': 'http://www.ncbi.nlm.nih.gov/gene/55768',
#      'label': 'NGLY1',
#      'synonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'peptide:N-glycanase',
#       'N-glycanase 1',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'CDDG',
#       'FLJ12409']},
#     {'equivalentOriginalNodeTarget': 'http://www.kegg.jp/dbget-bin/www_bget?hsa:55768',
#      'iri': 'http://purl.obolibrary.org/obo/GENO_0000418',
#      'isDefinedBy': 'https://data.monarchinitiative.org/ttl/kegg.ttl',
#      'lbl': 'has_affected_locus',
#      'type': 'http://purl.obolibrary.org/obo/GENO_0000418'},
#     {'Neo4jLabel': ['anonymous', 'Node', 'variant locus', 'cliqueLeader'],
#      'category': 'variant locus',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'some variant of K01456 peptide-N4-(N-acetyl-beta-glucosaminyl)asparagine amidase [EC:3.5.1.52] | (RefSeq) NGLY1',
#      'https://monarchinitiative.org/MONARCH_anonymous': True,
#      'iri': 'https://monarchinitiative.org/.well-known/genid/KEGG-hsa55768-OMIM615273VL',
#      'label': 'some variant of K01456 peptide-N4-(N-acetyl-beta-glucosaminyl)asparagine amidase [EC:3.5.1.52] | (RefSeq) NGLY1'},
#     {'iri': 'http://purl.obolibrary.org/obo/RO_0002607',
#      'isDefinedBy': 'https://data.monarchinitiative.org/ttl/kegg.ttl',
#      'lbl': 'is marker for',
#      'type': 'http://purl.obolibrary.org/obo/RO_0002607'},
#     {'Neo4jLabel': ['Class', 'Node', 'disease', 'cliqueLeader'],
#      'category': 'disease',
#      'definition': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://purl.obolibrary.org/obo/IAO_0000115': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['DOID:0060728',
#       'ICD10:E77.8',
#       'OMIM:615273',
#       'Orphanet:404454',
#       'UMLS:C3808991'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'congenital disorder of deglycosylation'],
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'mondo',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'Cdg Iv',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Cdg Iv, Formerly'],
#      'http://www.geneontology.org/formats/oboInOwl#id': 'OMIM:615273',
#      'http://www.w3.org/2000/01/rdf-schema#label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'iri': 'http://purl.obolibrary.org/obo/OMIM_615273',
#      'label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'synonym': ['CDDG',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'Cdg Iv',
#       'Cdg Iv, Formerly',
#       'congenital disorder of deglycosylation']}],
#    'overview': '(83497)<--[http://purl.obolibrary.org/obo/GENO_0000418,123017893]--(499685)--[http://purl.obolibrary.org/obo/RO_0002607,1521721]-->(179791)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'gene',
#       'sequence feature',
#       'cliqueLeader'],
#      'category': ['gene', 'sequence feature'],
#      'http://purl.org/dc/elements/1.1/description': ['N-glycanase 1',
#       'Peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'N-glycanase 1',
#       'FLJ12409'],
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['peptide:N-glycanase',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'PNG1',
#       'CDDG'],
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NGLY1',
#      'iri': 'http://www.ncbi.nlm.nih.gov/gene/55768',
#      'label': 'NGLY1',
#      'synonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'peptide:N-glycanase',
#       'N-glycanase 1',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'CDDG',
#       'FLJ12409']},
#     {'iri': 'http://purl.obolibrary.org/obo/GENO_0000418',
#      'isDefinedBy': 'http://data.monarchinitiative.org/ttl/clinvar.ttl',
#      'lbl': 'has_affected_locus',
#      'type': 'http://purl.obolibrary.org/obo/GENO_0000418'},
#     {'Neo4jLabel': ['Node',
#       'sequence alteration',
#       'snv',
#       'sequence feature',
#       'cliqueLeader'],
#      'category': ['sequence alteration', 'snv', 'sequence feature'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['NC_000003.12:g.25720179G>A',
#       'NM_001145293.1:c.1570C>T',
#       'NM_001145295.1:c.1612-544C>T',
#       'NP_001138765.1:p.Arg524Ter',
#       'NC_000003.11:g.25761670G>A',
#       'NG_034108.1:g.74861C>T',
#       'NM_001145294.1:c.1498C>T',
#       'NP_001138766.1:p.Arg500Ter'],
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NM_001145293.1(NGLY1):c.1570C>T (p.Arg524Ter)',
#      'iri': 'http://www.ncbi.nlm.nih.gov/clinvar/variation/126424',
#      'label': 'NM_001145293.1(NGLY1):c.1570C>T (p.Arg524Ter)',
#      'synonym': ['NC_000003.12:g.25720179G>A',
#       'NM_001145293.1:c.1570C>T',
#       'NM_001145295.1:c.1612-544C>T',
#       'NP_001138765.1:p.Arg524Ter',
#       'NC_000003.11:g.25761670G>A',
#       'NG_034108.1:g.74861C>T',
#       'NM_001145294.1:c.1498C>T',
#       'NP_001138766.1:p.Arg500Ter']},
#     {'iri': 'http://purl.obolibrary.org/obo/GENO_0000840',
#      'isDefinedBy': 'http://data.monarchinitiative.org/ttl/clinvar.ttl',
#      'lbl': 'pathogenic_for_condition',
#      'type': 'http://purl.obolibrary.org/obo/GENO_0000840'},
#     {'Neo4jLabel': ['Class', 'Node', 'disease', 'cliqueLeader'],
#      'category': 'disease',
#      'definition': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://purl.obolibrary.org/obo/IAO_0000115': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['DOID:0060728',
#       'ICD10:E77.8',
#       'OMIM:615273',
#       'Orphanet:404454',
#       'UMLS:C3808991'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'congenital disorder of deglycosylation'],
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'mondo',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'Cdg Iv',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Cdg Iv, Formerly'],
#      'http://www.geneontology.org/formats/oboInOwl#id': 'OMIM:615273',
#      'http://www.w3.org/2000/01/rdf-schema#label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'iri': 'http://purl.obolibrary.org/obo/OMIM_615273',
#      'label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'synonym': ['CDDG',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'Cdg Iv',
#       'Cdg Iv, Formerly',
#       'congenital disorder of deglycosylation']}],
#    'overview': '(83497)<--[http://purl.obolibrary.org/obo/GENO_0000418,20478895]--(5163627)--[http://purl.obolibrary.org/obo/GENO_0000840,21633520]-->(179791)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'gene',
#       'sequence feature',
#       'cliqueLeader'],
#      'category': ['gene', 'sequence feature'],
#      'http://purl.org/dc/elements/1.1/description': ['N-glycanase 1',
#       'Peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'N-glycanase 1',
#       'FLJ12409'],
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['peptide:N-glycanase',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'PNG1',
#       'CDDG'],
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NGLY1',
#      'iri': 'http://www.ncbi.nlm.nih.gov/gene/55768',
#      'label': 'NGLY1',
#      'synonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'peptide:N-glycanase',
#       'N-glycanase 1',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'CDDG',
#       'FLJ12409']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/OMIM_610661',
#      'lbl': 'isDefinedBy',
#      'type': 'isDefinedBy'},
#     {'Neo4jLabel': ['Ontology', 'Node', 'cliqueLeader'],
#      'iri': 'https://data.monarchinitiative.org/ttl/omim.ttl'},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/UMLS_C3808991',
#      'lbl': 'isDefinedBy',
#      'type': 'isDefinedBy'},
#     {'Neo4jLabel': ['Class', 'Node', 'disease', 'cliqueLeader'],
#      'category': 'disease',
#      'definition': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://purl.obolibrary.org/obo/IAO_0000115': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['DOID:0060728',
#       'ICD10:E77.8',
#       'OMIM:615273',
#       'Orphanet:404454',
#       'UMLS:C3808991'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'congenital disorder of deglycosylation'],
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'mondo',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'Cdg Iv',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Cdg Iv, Formerly'],
#      'http://www.geneontology.org/formats/oboInOwl#id': 'OMIM:615273',
#      'http://www.w3.org/2000/01/rdf-schema#label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'iri': 'http://purl.obolibrary.org/obo/OMIM_615273',
#      'label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'synonym': ['CDDG',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'Cdg Iv',
#       'Cdg Iv, Formerly',
#       'congenital disorder of deglycosylation']}],
#    'overview': '(83497)--[isDefinedBy,123017820]-->(275490)<--[isDefinedBy,123421668]--(179791)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'gene',
#       'sequence feature',
#       'cliqueLeader'],
#      'category': ['gene', 'sequence feature'],
#      'http://purl.org/dc/elements/1.1/description': ['N-glycanase 1',
#       'Peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'N-glycanase 1',
#       'FLJ12409'],
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['peptide:N-glycanase',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'PNG1',
#       'CDDG'],
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NGLY1',
#      'iri': 'http://www.ncbi.nlm.nih.gov/gene/55768',
#      'label': 'NGLY1',
#      'synonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'peptide:N-glycanase',
#       'N-glycanase 1',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'CDDG',
#       'FLJ12409']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/OMIM_610661',
#      'lbl': 'isDefinedBy',
#      'type': 'isDefinedBy'},
#     {'Neo4jLabel': ['Ontology', 'Node', 'cliqueLeader'],
#      'iri': 'https://data.monarchinitiative.org/ttl/omim.ttl'},
#     {'equivalentOriginalNodeSource': 'http://www.orpha.net/ORDO/Orphanet_404454',
#      'lbl': 'isDefinedBy',
#      'type': 'isDefinedBy'},
#     {'Neo4jLabel': ['Class', 'Node', 'disease', 'cliqueLeader'],
#      'category': 'disease',
#      'definition': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://purl.obolibrary.org/obo/IAO_0000115': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['DOID:0060728',
#       'ICD10:E77.8',
#       'OMIM:615273',
#       'Orphanet:404454',
#       'UMLS:C3808991'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'congenital disorder of deglycosylation'],
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'mondo',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'Cdg Iv',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Cdg Iv, Formerly'],
#      'http://www.geneontology.org/formats/oboInOwl#id': 'OMIM:615273',
#      'http://www.w3.org/2000/01/rdf-schema#label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'iri': 'http://purl.obolibrary.org/obo/OMIM_615273',
#      'label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'synonym': ['CDDG',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'Cdg Iv',
#       'Cdg Iv, Formerly',
#       'congenital disorder of deglycosylation']}],
#    'overview': '(83497)--[isDefinedBy,123017820]-->(275490)<--[isDefinedBy,123421656]--(179791)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'gene',
#       'sequence feature',
#       'cliqueLeader'],
#      'category': ['gene', 'sequence feature'],
#      'http://purl.org/dc/elements/1.1/description': ['N-glycanase 1',
#       'Peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'N-glycanase 1',
#       'FLJ12409'],
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['peptide:N-glycanase',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'PNG1',
#       'CDDG'],
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NGLY1',
#      'iri': 'http://www.ncbi.nlm.nih.gov/gene/55768',
#      'label': 'NGLY1',
#      'synonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'peptide:N-glycanase',
#       'N-glycanase 1',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'CDDG',
#       'FLJ12409']},
#     {'equivalentOriginalNodeSource': 'http://purl.obolibrary.org/obo/OMIM_610661',
#      'lbl': 'isDefinedBy',
#      'type': 'isDefinedBy'},
#     {'Neo4jLabel': ['Ontology', 'Node', 'cliqueLeader'],
#      'iri': 'https://data.monarchinitiative.org/ttl/omim.ttl'},
#     {'lbl': 'isDefinedBy', 'type': 'isDefinedBy'},
#     {'Neo4jLabel': ['Class', 'Node', 'disease', 'cliqueLeader'],
#      'category': 'disease',
#      'definition': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://purl.obolibrary.org/obo/IAO_0000115': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['DOID:0060728',
#       'ICD10:E77.8',
#       'OMIM:615273',
#       'Orphanet:404454',
#       'UMLS:C3808991'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'congenital disorder of deglycosylation'],
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'mondo',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'Cdg Iv',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Cdg Iv, Formerly'],
#      'http://www.geneontology.org/formats/oboInOwl#id': 'OMIM:615273',
#      'http://www.w3.org/2000/01/rdf-schema#label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'iri': 'http://purl.obolibrary.org/obo/OMIM_615273',
#      'label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'synonym': ['CDDG',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'Cdg Iv',
#       'Cdg Iv, Formerly',
#       'congenital disorder of deglycosylation']}],
#    'overview': '(83497)--[isDefinedBy,123017820]-->(275490)<--[isDefinedBy,3185022]--(179791)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'gene',
#       'sequence feature',
#       'cliqueLeader'],
#      'category': ['gene', 'sequence feature'],
#      'http://purl.org/dc/elements/1.1/description': ['N-glycanase 1',
#       'Peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'N-glycanase 1',
#       'FLJ12409'],
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['peptide:N-glycanase',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'PNG1',
#       'CDDG'],
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NGLY1',
#      'iri': 'http://www.ncbi.nlm.nih.gov/gene/55768',
#      'label': 'NGLY1',
#      'synonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'peptide:N-glycanase',
#       'N-glycanase 1',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'CDDG',
#       'FLJ12409']},
#     {'iri': 'http://purl.obolibrary.org/obo/GENO_0000418',
#      'isDefinedBy': 'http://data.monarchinitiative.org/ttl/clinvar.ttl',
#      'lbl': 'has_affected_locus',
#      'type': 'http://purl.obolibrary.org/obo/GENO_0000418'},
#     {'Neo4jLabel': ['Node',
#       'sequence alteration',
#       'snv',
#       'sequence feature',
#       'cliqueLeader'],
#      'category': ['sequence alteration', 'snv', 'sequence feature'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['NC_000003.12:g.25733931T>A',
#       'NC_000003.11:g.25775422T>A',
#       'NM_001145294.1:c.1075A>T',
#       'NP_060767.2:p.Arg401Ter',
#       'NP_001138766.1:p.Arg359Ter',
#       'NG_034108.1:g.61109A>T',
#       'NM_018297.3:c.1201A>T'],
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NM_018297.3(NGLY1):c.1201A>T (p.Arg401Ter)',
#      'iri': 'http://www.ncbi.nlm.nih.gov/clinvar/variation/50962',
#      'label': 'NM_018297.3(NGLY1):c.1201A>T (p.Arg401Ter)',
#      'synonym': ['NC_000003.12:g.25733931T>A',
#       'NC_000003.11:g.25775422T>A',
#       'NM_001145294.1:c.1075A>T',
#       'NP_060767.2:p.Arg401Ter',
#       'NP_001138766.1:p.Arg359Ter',
#       'NG_034108.1:g.61109A>T',
#       'NM_018297.3:c.1201A>T']},
#     {'iri': 'http://purl.obolibrary.org/obo/GENO_0000840',
#      'isDefinedBy': 'http://data.monarchinitiative.org/ttl/clinvar.ttl',
#      'lbl': 'pathogenic_for_condition',
#      'type': 'http://purl.obolibrary.org/obo/GENO_0000840'},
#     {'Neo4jLabel': ['Class', 'Node', 'disease', 'cliqueLeader'],
#      'category': 'disease',
#      'definition': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://purl.obolibrary.org/obo/IAO_0000115': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['DOID:0060728',
#       'ICD10:E77.8',
#       'OMIM:615273',
#       'Orphanet:404454',
#       'UMLS:C3808991'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'congenital disorder of deglycosylation'],
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'mondo',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'Cdg Iv',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Cdg Iv, Formerly'],
#      'http://www.geneontology.org/formats/oboInOwl#id': 'OMIM:615273',
#      'http://www.w3.org/2000/01/rdf-schema#label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'iri': 'http://purl.obolibrary.org/obo/OMIM_615273',
#      'label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'synonym': ['CDDG',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'Cdg Iv',
#       'Cdg Iv, Formerly',
#       'congenital disorder of deglycosylation']}],
#    'overview': '(83497)<--[http://purl.obolibrary.org/obo/GENO_0000418,21057160]--(5363126)--[http://purl.obolibrary.org/obo/GENO_0000840,22202826]-->(179791)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'gene',
#       'sequence feature',
#       'cliqueLeader'],
#      'category': ['gene', 'sequence feature'],
#      'http://purl.org/dc/elements/1.1/description': ['N-glycanase 1',
#       'Peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'N-glycanase 1',
#       'FLJ12409'],
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['peptide:N-glycanase',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'PNG1',
#       'CDDG'],
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NGLY1',
#      'iri': 'http://www.ncbi.nlm.nih.gov/gene/55768',
#      'label': 'NGLY1',
#      'synonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'peptide:N-glycanase',
#       'N-glycanase 1',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'CDDG',
#       'FLJ12409']},
#     {'equivalentOriginalNodeTarget': 'http://purl.obolibrary.org/obo/OMIM_610661',
#      'iri': 'http://purl.obolibrary.org/obo/RO_0003301',
#      'isDefinedBy': 'http://data.monarchinitiative.org/ttl/coriell.ttl',
#      'lbl': 'is model of',
#      'type': 'http://purl.obolibrary.org/obo/RO_0003301'},
#     {'Neo4jLabel': ['Node', 'cell line', 'cliqueLeader'],
#      'category': 'cell line',
#      'http://purl.org/dc/elements/1.1/description': 'Clinically affected; onset of symptoms at 12 months old; diagnosed at 7 years of age; whole exome sequence analysis reveals the subject is compound heterozygous for a p.Q208X variant (p.Gln208Stop; c.622 C>T) in exon 4 and a p.G310G variant (p.Gly310Gly; c.930 C>T) in exon 6 of the NGLY1 gene; subject also found to be heterozygous for a c.4060 A>T mutation (Thr1354Ser) in the CACNA1S gene �� (malignant hyperthermia susceptibility; reported as ACMG incidental finding) Test was performed using genomic DNA; the whole exome sequence was mapped and analyzed in comparison with the published human genome build UCSC hg19 reference sequence;  father (not in repository) is heterozygous for the Q208X mutation in the NGLY1 gene; mother (not in repository) is heterozygous for the G310G mutation in the NGLY1 gene and heterozygous for the Thr1354Ser mutation in the CACNA1S gene; brother with similar phenotype and the same genetic test results as this subject is GM25330 (lymphoblast)/GM25344 (fibroblast); lymphoblast for this same subject is GM25331.',
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NIGMS-GM25343',
# ...
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'gene',
#       'sequence feature',
#       'cliqueLeader'],
#      'category': ['gene', 'sequence feature'],
#      'http://purl.org/dc/elements/1.1/description': ['N-glycanase 1',
#       'Peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'N-glycanase 1',
#       'FLJ12409'],
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['peptide:N-glycanase',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'PNG1',
#       'CDDG'],
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NGLY1',
#      'iri': 'http://www.ncbi.nlm.nih.gov/gene/55768',
#      'label': 'NGLY1',
#      'synonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'peptide:N-glycanase',
#       'N-glycanase 1',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'CDDG',
#       'FLJ12409']},
#     {'iri': 'http://purl.obolibrary.org/obo/GENO_0000418',
#      'isDefinedBy': 'http://data.monarchinitiative.org/ttl/clinvar.ttl',
#      'lbl': 'has_affected_locus',
#      'type': 'http://purl.obolibrary.org/obo/GENO_0000418'},
#     {'Neo4jLabel': ['Node',
#       'sequence alteration',
#       'sequence feature',
#       'cliqueLeader'],
#      'category': ['sequence alteration', 'sequence feature'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['NG_034108.1:g.62666dupG',
#       'NM_018297.3:c.1370dupG',
#       'NM_001145294.1:c.1244dupG',
#       'NC_000003.12:g.25732374dupC',
#       'NP_060767.2:p.Arg458Lysfs',
#       'NP_001138766.1:p.Arg416Lysfs',
#       'NC_000003.11:g.25773865dupC'],
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NM_018297.3(NGLY1):c.1370dupG (p.Arg458Lysfs)',
#      'iri': 'http://www.ncbi.nlm.nih.gov/clinvar/variation/126422',
#      'label': 'NM_018297.3(NGLY1):c.1370dupG (p.Arg458Lysfs)',
#      'synonym': ['NG_034108.1:g.62666dupG',
#       'NM_018297.3:c.1370dupG',
#       'NM_001145294.1:c.1244dupG',
#       'NC_000003.12:g.25732374dupC',
#       'NP_060767.2:p.Arg458Lysfs',
#       'NP_001138766.1:p.Arg416Lysfs',
#       'NC_000003.11:g.25773865dupC']},
#     {'iri': 'http://purl.obolibrary.org/obo/GENO_0000840',
#      'isDefinedBy': 'http://data.monarchinitiative.org/ttl/clinvar.ttl',
#      'lbl': 'pathogenic_for_condition',
#      'type': 'http://purl.obolibrary.org/obo/GENO_0000840'},
#     {'Neo4jLabel': ['Class', 'Node', 'disease', 'cliqueLeader'],
#      'category': 'disease',
#      'definition': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://purl.obolibrary.org/obo/IAO_0000115': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['DOID:0060728',
#       'ICD10:E77.8',
#       'OMIM:615273',
#       'Orphanet:404454',
#       'UMLS:C3808991'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'congenital disorder of deglycosylation'],
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'mondo',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'Cdg Iv',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Cdg Iv, Formerly'],
#      'http://www.geneontology.org/formats/oboInOwl#id': 'OMIM:615273',
#      'http://www.w3.org/2000/01/rdf-schema#label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'iri': 'http://purl.obolibrary.org/obo/OMIM_615273',
#      'label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'synonym': ['CDDG',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'Cdg Iv',
#       'Cdg Iv, Formerly',
#       'congenital disorder of deglycosylation']}],
#    'overview': '(83497)<--[http://purl.obolibrary.org/obo/GENO_0000418,20465955]--(5286030)--[http://purl.obolibrary.org/obo/GENO_0000840,21594779]-->(179791)'}},
#  {'path': {'details': [{'Neo4jLabel': ['Class',
#       'Node',
#       'gene',
#       'sequence feature',
#       'cliqueLeader'],
#      'category': ['gene', 'sequence feature'],
#      'http://purl.org/dc/elements/1.1/description': ['N-glycanase 1',
#       'Peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'N-glycanase 1',
#       'FLJ12409'],
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['peptide:N-glycanase',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'PNG1',
#       'CDDG'],
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NGLY1',
#      'iri': 'http://www.ncbi.nlm.nih.gov/gene/55768',
#      'label': 'NGLY1',
#      'synonym': ['NGLY1_HUMAN',
#       'NGLY1',
#       'PNG1',
#       'LOC95041',
#       'peptide:N-glycanase',
#       'N-glycanase 1',
#       'PNGase',
#       'hPNGase',
#       'CDG1V',
#       'peptide-N(4)-(N-acetyl-beta-glucosaminyl)asparagine amidase',
#       'CDDG',
#       'FLJ12409']},
#     {'equivalentOriginalNodeTarget': 'http://purl.obolibrary.org/obo/OMIM_610661',
#      'iri': 'http://purl.obolibrary.org/obo/RO_0003301',
#      'isDefinedBy': 'http://data.monarchinitiative.org/ttl/coriell.ttl',
#      'lbl': 'is model of',
#      'type': 'http://purl.obolibrary.org/obo/RO_0003301'},
#     {'Neo4jLabel': ['Node', 'cell line', 'cliqueLeader'],
#      'category': 'cell line',
#      'http://purl.org/dc/elements/1.1/description': 'Clinically affected; vanishing twin noted at 20 week ultrasound; pregnancy otherwise uncomplicated; delivered at full term;  birth weight: 2722g (10th centile); length: 51 cm (75th centile) and OFC: 35.2 cm (70th centile) at day of life 6; presented day of life 4 with hypotonia; poor feeding; dehydration; jaundice; and elevated alkaline phosphatase of 293 IU;GGT of 802 IU (70-295);ALT 51 (6-50 IU/L); AST 56 (10-60 IU/L) ; at age 2 weeks ALT rose to 201 and AST to 236; at 10 weeks ALT was 200 and AST 236; absent reflexes and global developmental delay noted in infancy; EEG in infancy noted epileptiform changes but no seizures noted as an infant; at 4 months left gaze preference noted; liver biopsy at age 6 months showed cirrhosis and diffuse macrosteatosis; electron microscopy revealed abundant intracytoplasmic neutral lipid and dilated endoplasmic reticulum but no inclusions were seen; repeat liver biopsy at age 1 year showed moderate cirrhosis with septal chronic inflammation and mild fatty changes; muscle biopsy at age 1 year showed minor variation in muscle fiber; but no evidence of metabolic diseases or mitochondrial changes; at 14 months weight was below 1st centile; length at 25th centile and OFC was at the 10th centile; at 2 years: large magnitude infantile esotropia and bilateral epiphora with mattering consistent with congenital dacryostenosis; age 3:chronic dacryocystitis; throughout childhood: recurrent redness and mattering of the eyes eventually diagnosed with chronic severe blepharitis; at 2 years 9 months weight; length and OFC were all below the 1st centile; electromyography (EMG) at age 4 years showed sensory motor polyneuropathy; predominantly axonal; abnormal movements noted since age 7 years; including chorea and myoclonus in arms and hands;  repeat EMG at age 8 years showed progression of axonal neuropathy; seizures began at age 10 with eyelid fluttering; eye deviation; and perioral cyanosis; EEG at age 10 showed generalized electrodecremental patterns representing subclinical generalized seizures; very frequent multifocal and generalized spike/polyspikes; lack of normal posterior dominant rhythm and reverse anterior-posterior gradient at wakefulness;  by age 11: subject developed scoliosis; osteopenia noted at femur fracture (DEXA scan showed Z score of -3.9 I the left hip and -4.0 in the right hip); Age 14 ophthalmology exam: chronic inferior exposure keratitis; inferior corneal thickening due to blink apraxia; subject remains non-ambulatory and non-verbal (communicates using a device; able to follow commands); age 14 physical exam: short stature; height 1137 cm (-3.5 SD); weight 25.8 kg (-5.1 SD); acquired macrocephaly; OFC 50.3 cm (-3.9 SD); asymmetric head; seborrheic dermatitis on scalp; myopathic face with bilateral ptosis; wide mouth with high arched palate;  and gingival hypertrophy; lungs coarse to auscultation; severe muscle atrophy; flexion contractures in hands; 2-3 cutaneous toe syndactyly; severe scoliosis; erythematous perifollicular hyperkeratotic papules on all extremities; Age 14 neurological exam: diffuse severe hypotonia; dystonia; areflexia in the lower extremities;  and choreoathetoid movements of the upper extremities;  right bicep/tricep reflex 2+; left bicep/tricep 1+; responsive to touch in all extremities; exome sequencing (UCSC hg19) of the NGLY1 gene revealed that the donor is a compound heterozygote for the following mutations: maternally inherited c.347C>G (p.S116X) in exon 3 and paternally inherited c.881+5G>T (IVS5+5G>T) in intron 5; predicted to abolish the splice donor site of exon 5 causing abnormal gene splicing; donor subject is also heterozygous for the p.G531R mutation in the MYBPC3 gene associated with hypertrophic cardiomyopathy; treatments/surgeries: at 2 years: nasolacrimal duct probing; incision of punctum and ballooning; at 2.5 years nasolacrimal duct stented; at 3 years nasolacrimal duct ballooned;  correct ...
#      'http://www.w3.org/2000/01/rdf-schema#label': 'NIGMS-GM25596',
#      'iri': 'https://catalog.coriell.org/0/Sections/Search/Sample_Detail.aspx?Ref=GM25596',
#      'label': 'NIGMS-GM25596'},
#     {'iri': 'http://purl.obolibrary.org/obo/RO_0003301',
#      'isDefinedBy': 'http://data.monarchinitiative.org/ttl/coriell.ttl',
#      'lbl': 'is model of',
#      'type': 'http://purl.obolibrary.org/obo/RO_0003301'},
#     {'Neo4jLabel': ['Class', 'Node', 'disease', 'cliqueLeader'],
#      'category': 'disease',
#      'definition': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://purl.obolibrary.org/obo/IAO_0000115': ['Congenital disorder of deglycosylation is an autosomal recessive multisystem disorder characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production. Other common features include microcephaly, intractable seizures, abnormal eye movements, and evidence of liver dysfunction. Liver biopsy shows cytoplasmic accumulation of storage material in vacuoles (summary by {1:Enns et al., 2014}).\n\nFor a discussion of the classification of congenital disorders of glycosylation, see CDG1A (OMIM:212065).',
#       'A carbohydrate metabolic disorder that has_material_basis_in homozygous or compound heterozygous mutation in the NGLY1 gene on chromosome 1p24. It is characterized by global developmental delay, hypotonia, abnormal involuntary movements, and alacrima or poor tear production.'],
#      'http://www.geneontology.org/formats/oboInOwl#hasDbXref': ['DOID:0060728',
#       'ICD10:E77.8',
#       'OMIM:615273',
#       'Orphanet:404454',
#       'UMLS:C3808991'],
#      'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': ['CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'congenital disorder of deglycosylation'],
#      'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace': 'mondo',
#      'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'Cdg Iv',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Cdg Iv, Formerly'],
#      'http://www.geneontology.org/formats/oboInOwl#id': 'OMIM:615273',
#      'http://www.w3.org/2000/01/rdf-schema#label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'iri': 'http://purl.obolibrary.org/obo/OMIM_615273',
#      'label': ['Congenital Disorder of Deglycosylation',
#       'Congenital disorder of deglycosylation',
#       'NGLY1-deficiency'],
#      'synonym': ['CDDG',
#       'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#       'Congenital Disorder of Glycosylation, Type Iv, Formerly',
#       'deficiency of N-glycanase 1',
#       'NGLY1 deficiency',
#       'Congenital Disorder of Glycosylation, Type Iv',
#       'NGLY1-CDDG',
#       'congenital disorder of glycosylation type Iv',
#       'Cdg Iv',
#       'Cdg Iv, Formerly',
#       'congenital disorder of deglycosylation']}],
#    'overview': '(83497)<--[http://purl.obolibrary.org/obo/RO_0003301,123017827]--(208924)--[http://purl.obolibrary.org/obo/RO_0003301,193040]-->(179791)'}}]

# %%
# importantly, UNDIRECTED search results not include both DIRECTED search results

# %%
# draft
## s1-s2
# s1->s2
s = s1 
e = s2 
query='''
      MATCH path = allShortestPaths(
       (start:Node{iri:"'''+s+'''"})-['''+rel+'''*..'''+md+''']->(end:Node{iri:"'''+e+'''"})
      )
      RETURN path
'''

# api call 
data = {
    'cypherQuery':query,
    'limit':1000
}
r = requests.get('{}{}'.format(api,endpoint), params=data)
print('n1 -> n2 number of paths: {}'.format(len(r.json())))
n1_to_n2 = r.json()

# s2->s1
s = s2 
e = s1 
query='''
      MATCH path = allShortestPaths(
       (start:Node{iri:"'''+s+'''"})-['''+rel+'''*..'''+md+''']->(end:Node{iri:"'''+e+'''"})
      )
      RETURN path
'''

# api call 
data = {
    'cypherQuery':query,
    'limit':1000
}
r = requests.get('{}{}'.format(api,endpoint), params=data)
print('n2 -> n1 number of paths: {}'.format(len(r.json())))
n2_to_n1 = r.json()

# s1-s2
s = s1 
e = s2
query='''
      MATCH path = allShortestPaths(
       (start:Node{iri:"'''+s+'''"})-['''+rel+'''*..'''+md+''']-(end:Node{iri:"'''+e+'''"})
      )
      RETURN path
'''

# api call 
data = {
    'cypherQuery':query,
    'limit':1000
}
r = requests.get('{}{}'.format(api,endpoint), params=data)
print('n1 - n2 number of paths: {}'.format(len(r.json())))
n1_n2 = r.json()

# save ALL 3 search results in one file: append three lists
results = n1_to_n2 + n2_to_n1 + n1_n2
with open('{}/node{}_node{}_monarch_shortest2.json'.format(outdir, s.rsplit('/',1)[1], e.rsplit('/',1)[1]), 'w') as f:
    json.dump(results, f, sort_keys=True, indent=4)
# Out:
# n1 -> n2 number of paths: 0
# n2 -> n1 number of paths: 0
# n1 - n2 number of paths: 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-d4d191b1d8bc> in <module>()
#      60 # save ALL 3 search results in one file: append three lists
#      61 results = n1_to_n2 + n2_to_n1 + n1_n2
# ---> 62 with open('{}/node{}_node{}_monarch_shortest2.json'.format(outdir, s.rsplit('/',1)[1], e.rsplit('/',1)[1]), 'w') as f:
#      63     json.dump(results, f, sort_keys=True, indent=4)
#
# IndexError: list index out of range

# %% [markdown]
# #### Experiment

# %%
# parameters
# api address
api = 'https://scigraph-data.monarchinitiative.org/scigraph'
endpoint = '/cypher/execute.json'

# namespace iris
obo = 'http://purl.obolibrary.org/obo/'
ncbigene = 'http://www.ncbi.nlm.nih.gov/gene/'

# nodes
s1 = obo + 'OMIM_615273' #'OMIM:615273' -> obo + s1
s2 = ncbigene + '55768' #'NCBIGene:55768' -> ncbigene + geneid
e1 = ncbigene + '358' #'NCBIGene:358'
e2 = ncbigene + '11826' #'NCBIGene:11826'
e3 = obo + 'CHEBI_506227' #'CHEBI:506227' -> obo + e3

# type of relationships
rel = ''

# maximum depth
md = '15'

# function to query the api
def scigraphAllShortestPaths(api, endpoint, s, e, rel, md, directed=True):
    '''This function calls the monarch api '/cypher/execute' to find all shortest paths between two nodes'''
    
    query='''
      MATCH path = allShortestPaths(
       (start:Node{iri:"'''+s+'''"})-['''+rel+'''*..'''+md+''']->(end:Node{iri:"'''+e+'''"})
      )
      RETURN path
    '''
    if not directed:
        query='''
            MATCH path = allShortestPaths(
             (start:Node{iri:"'''+s+'''"})-['''+rel+'''*..'''+md+''']-(end:Node{iri:"'''+e+'''"})
            )
            RETURN path
        '''

    # api call 
    data = {
        'cypherQuery':query,
        'limit':1000
    }
    r = requests.get('{}{}'.format(api,endpoint), params=data)
    
    return r.json()

# %%
### retrieve hypothesis between s1 - s2
## s1-s2
# s1->s2 DIRECTED
s = s1 
e = s2 
print('n1: {} - n2: {}'.format(s,e))
n1_to_n2 = scigraphAllShortestPaths(api, endpoint, s, e, rel, md, directed=True)
print('n1 -> n2 number of paths: {}'.format(len(n1_to_n2)))


# s2->s1 DIRECTED
s = s2 
e = s1 
n2_to_n1 = scigraphAllShortestPaths(api, endpoint, s, e, rel, md, directed=True)
print('n2 -> n1 number of paths: {}'.format(len(n2_to_n1)))


# s1-s2 UNRECTED
s = s1 
e = s2
n1_n2 = scigraphAllShortestPaths(api, endpoint, s, e, rel, md, directed=False)
print('n1 - n2 number of paths: {}'.format(len(n1_n2)))

# save ALL 3 search results in one file: append three lists
results = n1_to_n2 + n2_to_n1 + n1_n2
with open('{}/node{}_node{}_monarch_shortest.json'.format(outdir, s.rsplit('/',1)[1], e.rsplit('/',1)[1]), 'w') as f:
    json.dump(results, f, sort_keys=True, indent=4)
# Out:
# n1: http://purl.obolibrary.org/obo/OMIM_615273 - n2: http://www.ncbi.nlm.nih.gov/gene/55768
# n1 -> n2 number of paths: 1
# n2 -> n1 number of paths: 5
# n1 - n2 number of paths: 27

# %%
### retrieve hypothesis between starts{s1,s2} - ends{e1,e2,e3}
for start in [s1, s2]:
    for end in [e1, e2, e3]:
        ## start-end
        # s->e DIRECTED
        s = start 
        e = end 
        print('n1: {} - n2: {}'.format(s,e))
        n1_to_n2 = scigraphAllShortestPaths(api, endpoint, s, e, rel, md, directed=True)
        print('n1 -> n2 number of paths: {}'.format(len(n1_to_n2)))


        # e->s DIRECTED
        s = end 
        e = start 
        n2_to_n1 = scigraphAllShortestPaths(api, endpoint, s, e, rel, md, directed=True)
        print('n2 -> n1 number of paths: {}'.format(len(n2_to_n1)))


        # s-e UNDIRECTED
        s = start 
        e = end
        n1_n2 = scigraphAllShortestPaths(api, endpoint, s, e, rel, md, directed=False)
        print('n1 - n2 number of paths: {}'.format(len(n1_n2)))

        # save ALL 3 search results in one file: append three lists
        results = n1_to_n2 + n2_to_n1 + n1_n2
        with open('{}/node{}_node{}_monarch_shortest.json'.format(outdir, s.rsplit('/',1)[1], e.rsplit('/',1)[1]), 'w') as f:
            json.dump(results, f, sort_keys=True, indent=4)
# Out:
# n1: http://purl.obolibrary.org/obo/OMIM_615273 - n2: http://www.ncbi.nlm.nih.gov/gene/358
# n1 -> n2 number of paths: 5
# n2 -> n1 number of paths: 20
# n1 - n2 number of paths: 3
# n1: http://purl.obolibrary.org/obo/OMIM_615273 - n2: http://www.ncbi.nlm.nih.gov/gene/11826
# n1 -> n2 number of paths: 61
# n2 -> n1 number of paths: 0
# n1 - n2 number of paths: 648
# n1: http://purl.obolibrary.org/obo/OMIM_615273 - n2: http://purl.obolibrary.org/obo/CHEBI_506227
# n1 -> n2 number of paths: 0
# n2 -> n1 number of paths: 0
# n1 - n2 number of paths: 4
# n1: http://www.ncbi.nlm.nih.gov/gene/55768 - n2: http://www.ncbi.nlm.nih.gov/gene/358
# n1 -> n2 number of paths: 5
# n2 -> n1 number of paths: 4
# n1 - n2 number of paths: 61
# n1: http://www.ncbi.nlm.nih.gov/gene/55768 - n2: http://www.ncbi.nlm.nih.gov/gene/11826
# n1 -> n2 number of paths: 58
# n2 -> n1 number of paths: 0
# n1 - n2 number of paths: 25
# n1: http://www.ncbi.nlm.nih.gov/gene/55768 - n2: http://purl.obolibrary.org/obo/CHEBI_506227
# n1 -> n2 number of paths: 0
# n2 -> n1 number of paths: 0
# n1 - n2 number of paths: 41

# %%
## s1-e1
s = s1 
e = e1
n1_n2 = scigraphAllShortestPaths(api, endpoint, s, e, rel, md, directed=True)
print('n1 - n2 number of paths: {}'.format(len(n1_n2)))
# Out:
# n1 - n2 number of paths: 5

# %%
## s1-e2
s = s1 
e = e2
n1_n2 = scigraphAllShortestPaths(api, endpoint, s, e, rel, md, directed=True)
print('n1 - n2 number of paths: {}'.format(len(n1_n2)))
# Out:
# n1 - n2 number of paths: 61

# %%
## s1-e3
s = s1 
e = e3
n1_n2 = scigraphAllShortestPaths(api, endpoint, s, e, rel, md, directed=True)
print('n1 - n2 number of paths: {}'.format(len(n1_n2)))
# Out:
# n1 - n2 number of paths: 0

# %%
## s2-e1
s = s2 
e = e1
n1_n2 = scigraphAllShortestPaths(api, endpoint, s, e, rel, md, directed=True)
print('n1 - n2 number of paths: {}'.format(len(n1_n2)))
# Out:
# n1 - n2 number of paths: 5

# %%
## s2-e2
s = s2 
e = e2
n1_n2 = scigraphAllShortestPaths(api, endpoint, s, e, rel, md, directed=True)
print('n1 - n2 number of paths: {}'.format(len(n1_n2)))
# Out:
# n1 - n2 number of paths: 58

# %%
## s2-e3
s = s2 
e = e3
n1_n2 = scigraphAllShortestPaths(api, endpoint, s, e, rel, md, directed=True)
print('n1 - n2 number of paths: {}'.format(len(n1_n2)))
# Out:
# n1 - n2 number of paths: 0
